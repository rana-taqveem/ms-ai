# %%
from torch import torch, nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torchvision.transforms.functional as TF
import random
import numpy as np
from skimage.feature import hog

# %%
isLocal = False
isColab = True

if isLocal:
    SAVE_PATH = './best_model_mlp.pth'
elif isColab:
    from google.colab import drive
    import os
    drive.mount('/content/drive', force_remount=True)
    os.chdir('/content/drive/MyDrive/MSAI/AI-600/assignment_02/')
    SAVE_PATH = '/content/drive/MyDrive/MSAI/AI-600/assignment_02/best_model_mlp.pth'
# Out:
# Mounted at /content/drive

# %%
import os
from torch.utils.data.dataset import TensorDataset
from torch.utils.data import random_split

def load_data():
    print(f"Current Working Directory: {os.getcwd()}")
    print(f"Files in this folder: {os.listdir('.')}")
    training_data = np.load('quickdraw_train.npz')
    testimgdata = np.load('quickdraw_test.npz')
    print(f"keys in training files:{training_data.files}")
    train_images = training_data['x_train']
    train_labels = training_data['y_train']
    class_names = training_data['class_names']
    print(f"keys in files:{testimgdata.files}")
    test_images = testimgdata['test_images']
    print(train_images.shape)
    print(train_labels.shape)
    print(len(class_names))
    print(test_images.shape)
    return train_images, train_labels, test_images

def prepare_data(x, y=None):
  images = torch.from_numpy(x).float()/255.0
  images = images.view(images.shape[0], 1, 28, 28)
  if len(images.shape) > 2:
    images = images.view(images.shape[0], -1)

  print(images.shape)
  if y is not None:
    labels = torch.from_numpy(y).long()
    print(labels.shape)
    print(labels[0])
    return TensorDataset(images, labels)
  else:
    return TensorDataset(images)

# %%
BATCH_SIZE = 48
DEVICE = "cpu"

train_images, train_labels, test_images = load_data()

train_data = prepare_data(train_images, train_labels)
test_data = prepare_data(test_images)

generator = torch.Generator().manual_seed(42)
total_size = len(train_data)
train_size = int(0.8 * total_size)
val_size = total_size - train_size
train_data, val_data = random_split(train_data,
                                   [train_size, val_size],
                                    generator=generator)

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)

test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)


print(f"Train size: {len(train_data)}")
print(f"Val size: {len(val_data)}")
print(f"Test size: {len(test_data)}")
# Out:
# Current Working Directory: /content/drive/MyDrive/MSAI/AI-600/assignment_02
# Files in this folder: ['quickdraw_train.npz', 'quickdraw_test.npz', 'best_model_mlp.pthbest_model_mlp.pth', 'Copy of best_model_mlp.pth', 'best_model_256_3_128_3.pth', 'best_model_mlp.pth']
# keys in training files:['x_train', 'y_train', 'class_names']
# keys in files:['test_images']
# (60000, 784)
# (60000,)
# 15
# (15000, 784)
# torch.Size([60000, 784])
# torch.Size([60000])
# tensor(0)
# torch.Size([15000, 784])
# Train size: 48000
# Val size: 12000
# Test size: 15000

# %%
import matplotlib.pyplot as plt

img_tensor = torch.from_numpy(train_images[0])

img_tensor = img_tensor.view(1, 28, 28)
img_tensor = img_tensor.permute(1, 2, 0)
plt.imshow(img_tensor, cmap='gray')
plt.show()


img_tensor = torch.from_numpy(test_images[0])

img_tensor = img_tensor.view(1, 28, 28)
img_tensor = img_tensor.permute(1, 2, 0)
plt.imshow(img_tensor, cmap='gray')
plt.show()

# %%
HOG_PIXEL_PER_CELL = (4, 4)
HOG_CELL_PER_BLOCK = (2, 2)
HOG_ORIENTATIONS = 8

def get_hog_features(images_tensor):
  images_np = images_tensor.cpu().numpy()
  hog_features = []

  for image in images_np:
    image = image.reshape(28, 28)
    fd = hog(image,
             orientations=HOG_ORIENTATIONS,
             pixels_per_cell=HOG_PIXEL_PER_CELL,
             cells_per_block=HOG_CELL_PER_BLOCK, visualize=False)

    hog_features.append(fd)

  return torch.tensor(np.array(hog_features), dtype=torch.float32).to(DEVICE)

def calculate_hog_size(image_shape=(28, 28)):
  dummy_img = np.zeros(image_shape)
  fd = hog(dummy_img,
           orientations=HOG_ORIENTATIONS,
           pixels_per_cell=HOG_PIXEL_PER_CELL,
           cells_per_block=HOG_CELL_PER_BLOCK)

  return len(fd)

def apply_augmentation(images_tensor):

  images = images_tensor.view(-1, 1, 28, 28)
  augmented_image = []
  for i in range(images.shape[0]):
    img = images[i]

    angle = random.uniform(-15, 15)
    img = TF.rotate(img, angle)

    shift_x, shift_y = np.random.randint(-2,2), np.random.randint(-2,2)
    img = TF.affine(img, angle=0, translate=(shift_x, shift_y), scale=1.0, shear=0)

    augmented_image.append(img)

    images[i] = img

  return torch.stack(augmented_image).view(-1, 784)

# %%
class WideMLP(nn.Module):
  def __init__(self, input_size=784, num_class=15):
    super(WideMLP, self).__init__()
    self.fc1 = nn.Linear(input_size, 1048)
    self.fc2 = nn.Linear(1048, 1048)
    self.fc3 = nn.Linear(1048, num_class)

  def forward(self, x):
    x0 = x.view(-1, 784)
    x1 = F.relu(self.fc1(x0))
    x2 = F.relu(self.fc2(x1))
    y_hat = self.fc3(x2)
    return y_hat

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
class DeepMLP(nn.Module):
  def __init__(self, input_size=784, num_class=15):
    super(DeepMLP, self).__init__()
    self.input_size = input_size
    self.num_class = num_class
    self.fc1 = nn.Linear(self.input_size, 256)
    self.bn1 = nn.BatchNorm1d(256)

    self.fc2 = nn.Linear(256, 256)
    self.bn2 = nn.BatchNorm1d(256)

    self.fc3 = nn.Linear(256, 128)
    self.bn3 = nn.BatchNorm1d(128)

    self.fc4 = nn.Linear(128, 128)
    self.bn4 = nn.BatchNorm1d(128)

    # self.fc5 = nn.Linear(64, 32)
    # self.bn5 = nn.BatchNorm1d(32)

    self.fc6 = nn.Linear(128, self.num_class)

    self.drop_light = nn.Dropout(0.2)
    self.drop_heavy = nn.Dropout(0.4)

  def forward(self, x):
    # x = x.view(-1, 784)
    # print(x.shape)
    x = F.gelu(self.bn1(self.fc1(x)))
    x = self.drop_heavy(F.gelu(self.bn2(self.fc2(x))))
    x = self.drop_light(F.gelu(self.bn3(self.fc3(x))))
    x = F.gelu(self.bn4(self.fc4(x)))
    # x = F.gelu(self.bn5(self.fc5(x)))
    y_hat = self.fc6(x)
    return y_hat

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def get_gradients_norm(model):
    grad_norms = {}
    for name, p in model.named_parameters():
        if p.grad is not None:
            grad_norms[name] = p.grad.detach().data.norm(2).item()

    return grad_norms

# %%
def train_one_epoch(model, train_data, criterion, optimizer, grad_history=None):
    model.train()
    total_loss, accurate_predictions, sample_count = 0.0, 0, 0
    for images, labels in train_data:
      images = images.to(DEVICE)
      labels = labels.to(DEVICE)

      aug_images = apply_augmentation(images)
      hog_features = get_hog_features(aug_images)

      flat_aug = aug_images.view(-1, 784)
      images = torch.cat((flat_aug, hog_features), dim=1)

      optimizer.zero_grad()
      outputs = model(images)
      loss = criterion(outputs, labels)
      loss.backward()


      norms = get_gradients_norm(model)
      for name, norm in norms.items():
          grad_history[name].append(norm)

      optimizer.step()

      total_loss += loss.item() * images.size(0)
      _, predicted_classes = torch.max(outputs.data, 1)
      accurate_predictions += (predicted_classes == labels).sum().item()
      sample_count += images.size(0)

    avg_loss = total_loss / sample_count
    accuracy =  100 * accurate_predictions / sample_count

    return avg_loss, accuracy

def evaluate(model, loader, criterion):
    model.eval()
    total_loss, accurate_predictions, sample_count = 0.0, 0, 0
    with torch.no_grad():
      for images, labels in loader:
          images = images.to(DEVICE)
          labels = labels.to(DEVICE)

          hog_features = get_hog_features(images)
          flat_images = images.view(-1, 784)
          images = torch.cat((flat_images, hog_features), dim=1)

          outputs = model(images)
          loss = criterion(outputs, labels)

          _, predicted_classes = torch.max(outputs, 1)

          accurate_predictions += (predicted_classes == labels).sum().item()
          total_loss += loss.item() * images.size(0)
          sample_count += images.size(0)

    avg_loss = total_loss / sample_count
    accuracy =  100 * accurate_predictions / sample_count

    return avg_loss, accuracy

# %%
def confusion_mat(model, loader):
  model.eval()
  all_preds, all_labels = [], []

  with torch.no_grad():
      for images, labels in val_loader:
          images = images.to(DEVICE)
          labels = labels.to(DEVICE)
          hog_features = get_hog_features(images)
          flat_images = images.view(-1, 784)
          images = torch.cat((flat_images, hog_features), dim=1)

          outputs = model(images.to(DEVICE))
          all_preds.extend(outputs.argmax(1).cpu().numpy())
          all_labels.extend(labels.numpy())

  cm = confusion_matrix(all_labels, all_preds)
  plt.figure(figsize=(10,8))
  sns.heatmap(cm, annot=True, fmt='d')
  plt.xlabel('Predicted')
  plt.ylabel('Actual')
  plt.show()

# %%
import copy
from sklearn.metrics import confusion_matrix
import seaborn as sns
best_model_weights = None

def train_model(model:nn.Module, epochs = 40, learning_rate=0.001, weight_decay=1e-3, grad_history=None):
  print(f"Training model for {epochs} epochs")
  print(f"Learning rate: {learning_rate}")
  print(f"Weight Decay: {weight_decay}")


  best_val_loss = float('inf')
  train_losses, train_accs, val_losses, val_accs = [], [], [], []

  criterion_cel = nn.CrossEntropyLoss(label_smoothing=0.1)

  optimizer_adam = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

  # best working so far
  scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer_adam, mode='min', factor=0.3, patience=3, threshold=1e-3)

  for epoch in range(0, epochs):
    train_loss, train_acc = train_one_epoch(model=model,
                                            train_data=train_loader,
                                            criterion=criterion_cel,
                                            optimizer=optimizer_adam,
                                            grad_history=grad_history)

    val_loss, val_acc = evaluate(model, val_loader, criterion=criterion_cel)

    if val_loss < best_val_loss:
      best_val_loss = val_loss
      best_model_weights = copy.deepcopy(model.state_dict())
      torch.save(best_model_weights, SAVE_PATH)
      print(f"---> Best model updated at Epoch: {epoch+1} (Validation Loss: {val_loss:.4f})")

    train_losses.append(train_loss)
    train_accs.append(train_acc)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    current_learning_rate = optimizer_adam.param_groups[0]['lr']

    print(f"Epoch: {epoch+1} (Learning Rate: {current_learning_rate:.6f})")

    scheduler.step(val_loss)
    print(f"Epoch: {epoch+1}) Training Loss: {train_loss:.4f} Training Accuracy: {train_acc:.2f}% Validation Loss {val_loss:.2f}% Validaion Accuracy:{val_acc:.2f}%")

  model.load_state_dict(best_model_weights)
  torch.save(model.state_dict(), SAVE_PATH)
  print("Training complete. Loaded best model weights")
  print(f"Best model saved at {SAVE_PATH}")
  confusion_mat(model, val_loader)

  return train_losses, train_accs, val_losses, val_accs

# %%
# # Initialize Wide model
# wide_model = WideMLP().to(DEVICE)
# print(f"WideMLP Parameters: {count_parameters(wide_model)}")

# EPOCHS = 20
# LEARNING_RATE = 0.0005
# L2_REGULARIZATION = 1e-3
# train_losses, train_acc, val_losses, val_acc = train_model(wide_model, epochs=EPOCHS, learning_rate=L2_REGULARIZATION)

# plt.figure(figsize=(15, 5))
# plt.subplot(1, 2, 1)
# plt.plot(train_losses, label='Training Loss', color='#1f77b4')
# plt.plot(val_losses, label='Validation Loss', color='#1f7f0e')
# plt.title('Wide MLP Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()

# plt.subplot(1, 2, 2)
# plt.plot(train_acc, label='Training Acc', color='#1f77b4')
# plt.plot(val_acc, label='Validation Acc', color='#1f7f0e')
# plt.title('Wide MLP Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
# Initialize Wide model
# Initialize model

input_size = calculate_hog_size() + 784
print(input_size)
deep_model = DeepMLP(input_size).to(DEVICE)
print(f"DeepMLP Parameters: {count_parameters(deep_model)}")

EPOCHS = 40
LEARNING_RATE = 1e-4
L2_REGULARIZATION = 1e-4
WEIGHTS_DECAY = 3e-4
grad_history = {name:[] for name, _ in deep_model.named_parameters()}
train_losses, train_acc, val_losses, val_acc = train_model(deep_model, epochs=EPOCHS, learning_rate=LEARNING_RATE, weight_decay=WEIGHTS_DECAY, grad_history=grad_history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss', color='#1f77b4')
plt.plot(val_losses, label='Validation Loss', color='#1f7f0e')
plt.title('Deep MLP Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Acc', color='#1f77b4')
plt.plot(val_acc, label='Validation Acc', color='#1f7f0e')
plt.title('Deep MLP Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1936
# DeepMLP Parameters: 614543
# Training model for 40 epochs
# Learning rate: 0.0001
# Weight Decay: 0.0003
# ---> Best model updated at Epoch: 1 (Validation Loss: 1.1896)
# Epoch: 1 (Learning Rate: 0.000100)
# Epoch: 1) Training Loss: 1.7405 Training Accuracy: 54.24% Validation Loss 1.19% Validaion Accuracy:75.48%
# ---> Best model updated at Epoch: 2 (Validation Loss: 1.0909)
# Epoch: 2 (Learning Rate: 0.000100)
# Epoch: 2) Training Loss: 1.3114 Training Accuracy: 69.96% Validation Loss 1.09% Validaion Accuracy:78.55%
# ---> Best model updated at Epoch: 3 (Validation Loss: 1.0453)
# Epoch: 3 (Learning Rate: 0.000100)
# Epoch: 3) Training Loss: 1.2347 Training Accuracy: 72.92% Validation Loss 1.05% Validaion Accuracy:80.83%
# ---> Best model updated at Epoch: 4 (Validation Loss: 1.0233)
# Epoch: 4 (Learning Rate: 0.000100)
# Epoch: 4) Training Loss: 1.1915 Training Accuracy: 74.41% Validation Loss 1.02% Validaion Accuracy:81.42%
# ---> Best model updated at Epoch: 5 (Validation Loss: 1.0068)
# Epoch: 5 (Learning Rate: 0.000100)
# Epoch: 5) Training Loss: 1.1673 Training Accuracy: 75.38% Validation Loss 1.01% Validaion Accuracy:81.77%
# ---> Best model updated at Epoch: 6 (Validation Loss: 0.9925)
# Epoch: 6 (Learning Rate: 0.000100)
# Epoch: 6) Training Loss: 1.1426 Training Accuracy: 76.25% Validation Loss 0.99% Validaion Accuracy:82.36%
# ---> Best model updated at Epoch: 7 (Validation Loss: 0.9839)
# Epoch: 7 (Learning Rate: 0.000100)
# Epoch: 7) Training Loss: 1.1259 Training Accuracy: 77.11% Validation Loss 0.98% Validaion Accuracy:82.92%
# ---> Best model updated at Epoch: 8 (Validation Loss: 0.9745)
# Epoch: 8 (Learning Rate: 0.000100)
# Epoch: 8) Training Loss: 1.1135 Training Accuracy: 77.52% Validation Loss 0.97% Validaion Accuracy:83.17%
# ---> Best model updated at Epoch: 9 (Validation Loss: 0.9713)
# Epoch: 9 (Learning Rate: 0.000100)
# Epoch: 9) Training Loss: 1.1000 Training Accuracy: 78.03% Validation Loss 0.97% Validaion Accuracy:83.52%
# ---> Best model updated at Epoch: 10 (Validation Loss: 0.9675)
# Epoch: 10 (Learning Rate: 0.000100)
# Epoch: 10) Training Loss: 1.0900 Training Accuracy: 78.62% Validation Loss 0.97% Validaion Accuracy:83.53%
# ---> Best model updated at Epoch: 11 (Validation Loss: 0.9591)
# Epoch: 11 (Learning Rate: 0.000100)
# Epoch: 11) Training Loss: 1.0842 Training Accuracy: 78.57% Validation Loss 0.96% Validaion Accuracy:83.85%
# ---> Best model updated at Epoch: 12 (Validation Loss: 0.9530)
# Epoch: 12 (Learning Rate: 0.000100)
# Epoch: 12) Training Loss: 1.0778 Training Accuracy: 78.91% Validation Loss 0.95% Validaion Accuracy:84.18%
# ---> Best model updated at Epoch: 13 (Validation Loss: 0.9504)
# Epoch: 13 (Learning Rate: 0.000100)
# Epoch: 13) Training Loss: 1.0682 Training Accuracy: 79.50% Validation Loss 0.95% Validaion Accuracy:84.22%
# Epoch: 14 (Learning Rate: 0.000100)
# Epoch: 14) Training Loss: 1.0614 Training Accuracy: 79.59% Validation Loss 0.95% Validaion Accuracy:84.22%
# ---> Best model updated at Epoch: 15 (Validation Loss: 0.9465)
# Epoch: 15 (Learning Rate: 0.000100)
# Epoch: 15) Training Loss: 1.0560 Training Accuracy: 79.75% Validation Loss 0.95% Validaion Accuracy:84.41%
# ---> Best model updated at Epoch: 16 (Validation Loss: 0.9426)
# Epoch: 16 (Learning Rate: 0.000100)
# Epoch: 16) Training Loss: 1.0515 Training Accuracy: 79.99% Validation Loss 0.94% Validaion Accuracy:84.38%
# ---> Best model updated at Epoch: 17 (Validation Loss: 0.9413)
# Epoch: 17 (Learning Rate: 0.000100)
# Epoch: 17) Training Loss: 1.0443 Training Accuracy: 80.47% Validation Loss 0.94% Validaion Accuracy:84.74%
# ---> Best model updated at Epoch: 18 (Validation Loss: 0.9412)
# Epoch: 18 (Learning Rate: 0.000100)
# Epoch: 18) Training Loss: 1.0395 Training Accuracy: 80.53% Validation Loss 0.94% Validaion Accuracy:84.76%
# ---> Best model updated at Epoch: 19 (Validation Loss: 0.9350)
# Epoch: 19 (Learning Rate: 0.000100)
# Epoch: 19) Training Loss: 1.0333 Training Accuracy: 80.74% Validation Loss 0.94% Validaion Accuracy:84.86%
# Epoch: 20 (Learning Rate: 0.000100)
# Epoch: 20) Training Loss: 1.0292 Training Accuracy: 80.88% Validation Loss 0.94% Validaion Accuracy:84.48%
# ---> Best model updated at Epoch: 21 (Validation Loss: 0.9288)
# Epoch: 21 (Learning Rate: 0.000100)
# Epoch: 21) Training Loss: 1.0281 Training Accuracy: 80.89% Validation Loss 0.93% Validaion Accuracy:84.94%
# ---> Best model updated at Epoch: 22 (Validation Loss: 0.9282)
# Epoch: 22 (Learning Rate: 0.000100)
# Epoch: 22) Training Loss: 1.0232 Training Accuracy: 81.20% Validation Loss 0.93% Validaion Accuracy:85.09%
# ---> Best model updated at Epoch: 23 (Validation Loss: 0.9245)
# Epoch: 23 (Learning Rate: 0.000100)
# Epoch: 23) Training Loss: 1.0237 Training Accuracy: 81.18% Validation Loss 0.92% Validaion Accuracy:85.34%
# ---> Best model updated at Epoch: 24 (Validation Loss: 0.9239)
# Epoch: 24 (Learning Rate: 0.000100)
# Epoch: 24) Training Loss: 1.0172 Training Accuracy: 81.48% Validation Loss 0.92% Validaion Accuracy:85.15%
# Epoch: 25 (Learning Rate: 0.000100)
# Epoch: 25) Training Loss: 1.0143 Training Accuracy: 81.50% Validation Loss 0.92% Validaion Accuracy:85.17%
# ---> Best model updated at Epoch: 26 (Validation Loss: 0.9224)
# Epoch: 26 (Learning Rate: 0.000100)
# Epoch: 26) Training Loss: 1.0084 Training Accuracy: 81.85% Validation Loss 0.92% Validaion Accuracy:85.24%
# ---> Best model updated at Epoch: 27 (Validation Loss: 0.9215)
# Epoch: 27 (Learning Rate: 0.000100)
# Epoch: 27) Training Loss: 1.0098 Training Accuracy: 81.80% Validation Loss 0.92% Validaion Accuracy:85.42%
# Epoch: 28 (Learning Rate: 0.000100)
# Epoch: 28) Training Loss: 1.0063 Training Accuracy: 82.04% Validation Loss 0.92% Validaion Accuracy:85.43%
# Epoch: 29 (Learning Rate: 0.000100)
# Epoch: 29) Training Loss: 1.0003 Training Accuracy: 82.08% Validation Loss 0.92% Validaion Accuracy:85.23%
# ---> Best model updated at Epoch: 30 (Validation Loss: 0.9173)
# Epoch: 30 (Learning Rate: 0.000100)
# Epoch: 30) Training Loss: 1.0010 Training Accuracy: 82.21% Validation Loss 0.92% Validaion Accuracy:85.78%
# Epoch: 31 (Learning Rate: 0.000100)
# Epoch: 31) Training Loss: 0.9939 Training Accuracy: 82.37% Validation Loss 0.92% Validaion Accuracy:85.18%
# ---> Best model updated at Epoch: 32 (Validation Loss: 0.9142)
# Epoch: 32 (Learning Rate: 0.000100)
# Epoch: 32) Training Loss: 0.9951 Training Accuracy: 82.40% Validation Loss 0.91% Validaion Accuracy:85.59%
# Epoch: 33 (Learning Rate: 0.000100)
# Epoch: 33) Training Loss: 0.9914 Training Accuracy: 82.58% Validation Loss 0.92% Validaion Accuracy:85.34%
# Epoch: 34 (Learning Rate: 0.000100)
# Epoch: 34) Training Loss: 0.9896 Training Accuracy: 82.73% Validation Loss 0.91% Validaion Accuracy:85.64%
# ---> Best model updated at Epoch: 35 (Validation Loss: 0.9116)
# Epoch: 35 (Learning Rate: 0.000100)
# Epoch: 35) Training Loss: 0.9915 Training Accuracy: 82.64% Validation Loss 0.91% Validaion Accuracy:85.94%
# Epoch: 36 (Learning Rate: 0.000100)
# Epoch: 36) Training Loss: 0.9873 Training Accuracy: 82.59% Validation Loss 0.91% Validaion Accuracy:85.92%
# Epoch: 37 (Learning Rate: 0.000100)
# Epoch: 37) Training Loss: 0.9847 Training Accuracy: 82.78% Validation Loss 0.91% Validaion Accuracy:85.58%
# ---> Best model updated at Epoch: 38 (Validation Loss: 0.9083)
# Epoch: 38 (Learning Rate: 0.000100)
# Epoch: 38) Training Loss: 0.9819 Training Accuracy: 82.84% Validation Loss 0.91% Validaion Accuracy:85.82%
# ---> Best model updated at Epoch: 39 (Validation Loss: 0.9082)
# Epoch: 39 (Learning Rate: 0.000100)
# Epoch: 39) Training Loss: 0.9837 Training Accuracy: 82.98% Validation Loss 0.91% Validaion Accuracy:86.12%
# Epoch: 40 (Learning Rate: 0.000100)
# Epoch: 40) Training Loss: 0.9834 Training Accuracy: 82.80% Validation Loss 0.91% Validaion Accuracy:85.72%
# Training complete. Loaded best model weights
# Best model saved at /content/drive/MyDrive/MSAI/AI-600/assignment_02/best_model_mlp.pth

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
for name, grads in grad_history.items():
    if 'weight' in name: # Focus on weights, ignore biases for clarity
        plt.plot(grads, label=name)

plt.title("Gradient Magnitudes per Layer")
plt.xlabel("Iterations")
plt.ylabel("L2 Norm of Gradient")
plt.legend()
plt.yscale('log') # Use log scale because magnitudes vary wildly
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_gradient_zoom(grad_history, layer_name='fc1.weight', limit=100):
    data = grad_history[layer_name][:limit]

    plt.figure(figsize=(12, 5))
    # Plotting with markers to see individual iterations
    plt.plot(data, marker='o', linestyle='-', markersize=4, color='#1f77b4', alpha=0.7)

    plt.title(f"Micro-View: Gradient Magnitude for {layer_name} (First {limit} Iterations)")
    plt.xlabel("Iteration (Step-by-Step)")
    plt.ylabel("Gradient Norm (L2)")
    plt.grid(True, alpha=0.3)

    # Annotate the "Start" and "End" of this window
    plt.annotate('Initial Shock', xy=(0, data[0]), xytext=(10, data[0]+0.5),
                 arrowprops=dict(facecolor='black', shrink=0.05))

    plt.show()

# Run this to see the "DNA" of your model's learning
plot_gradient_zoom(grad_history)

# %%
def run_predictions(model, loader):
  print(f"Evaluation on Test Set:")

  all_predictions = []
  model.eval()
  with torch.no_grad():
    for batch in loader:
      images = batch[0].to(DEVICE)
      # images = images.to(DEVICE)

      hog_features = get_hog_features(images)
      flat_images = images.view(-1, 784)
      images = torch.cat((flat_images, hog_features), dim=1)

      outputs = model(images)
      _, predictions = torch.max(outputs, 1)
      all_predictions.extend(predictions.cpu().numpy().tolist())

  return all_predictions


predictions = run_predictions(deep_model, test_loader)
predictions_string = ",".join(map(str, predictions))

output_file = "predictions.txt"

with open(output_file, "w") as f:
    f.write(predictions_string)

print(f"Predictions saved to {output_file}")
# Out:
# Evaluation on Test Set:
# Predictions saved to predictions.txt
