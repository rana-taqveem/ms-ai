# %%
from torch import torch, nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torchvision.transforms.functional as TF
import random
import numpy as np
from skimage.feature import hog
from seaborn import lineplot
import matplotlib.pyplot as plt

# %%
isLocal = True
isColab = False

if isLocal:
    SAVE_PATH = './best_model_mlp.pth'
elif isColab:
    from google.colab import drive
    import os
    drive.mount('/content/drive', force_remount=True)
    os.chdir('/content/drive/MyDrive/MSAI/AI-600/assignment_02/')
    SAVE_PATH = '/content/drive/MyDrive/MSAI/AI-600/assignment_02/best_model_mlp.pth'

# %%
import os
from torch.utils.data.dataset import TensorDataset
from torch.utils.data import random_split

def load_data():
    print(f"Current Working Directory: {os.getcwd()}")
    print(f"Files in this folder: {os.listdir('.')}")

    training_data = np.load('quickdraw_train.npz')
    testimgdata = np.load('quickdraw_test.npz')


    print(f"keys in training files:{training_data.files}")
    train_images = training_data['x_train']
    train_labels = training_data['y_train']
    class_names = training_data['class_names']


    print(f"keys in files:{testimgdata.files}")
    test_images = testimgdata['test_images']


    print(train_images.shape)
    print(train_labels.shape)
    print(len(class_names))

    print(test_images.shape)
    
    return train_images, train_labels, test_images

def prepare_data(x, y=None):
    
  images = torch.from_numpy(x).float()/255.0
  images = images.view(images.shape[0], 1, 28, 28)

  if len(images.shape) > 2:
    images = images.view(images.shape[0], -1)

  print(images.shape)
  
  if y is not None:
    labels = torch.from_numpy(y).long()
    print(labels.shape)
    print(labels[0])
    
    return TensorDataset(images, labels)
  
  else:
    return TensorDataset(images, None)

# %%
BATCH_SIZE = 48
DEVICE = "cpu"

train_images, train_labels, test_images = load_data()

train_data = prepare_data(train_images, train_labels)
test_data = prepare_data(test_images)

generator = torch.Generator().manual_seed(42)
total_size = len(train_data)
train_size = int(0.8 * total_size)
val_size = total_size - train_size
train_data, val_data = random_split(train_data,
                                   [train_size, val_size],
                                    generator=generator)

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)

test_loader = DataLoader(test_data, batch_size=256, shuffle=False)


print(f"Train size: {len(train_data)}")
print(f"Val size: {len(val_data)}")
print(f"Test size: {len(test_data)}")
# Out:
# Current Working Directory: d:\02-personal\01_ms ai\git-repo\600\assignment_02
# Files in this folder: ['25280030_pa2.ipynb', '25280030_pa2_light.ipynb', '25280030_pa2_optimized_1.ipynb', 'best_model_mlp.pth', 'leaderboard_credentials', 'PA2_Deep_Learning (1).pdf', 'PA2_Deep_Learning.pdf', 'quickdraw_test.npz', 'quickdraw_train.npz', 'requirements.txt', 'venv']
# keys in training files:['x_train', 'y_train', 'class_names']
# keys in files:['test_images']
# (60000, 784)
# (60000,)
# 15
# (15000, 784)
# torch.Size([60000, 784])
# torch.Size([60000])
# tensor(0)
# torch.Size([15000, 784])
# Train size: 48000
# Val size: 12000
# Test size: 15000

# %%
import matplotlib.pyplot as plt

img_tensor = torch.from_numpy(train_images[0])

img_tensor = img_tensor.view(1, 28, 28)
img_tensor = img_tensor.permute(1, 2, 0)
plt.imshow(img_tensor, cmap='gray')
plt.show()


img_tensor = torch.from_numpy(test_images[0])

img_tensor = img_tensor.view(1, 28, 28)
img_tensor = img_tensor.permute(1, 2, 0)
plt.imshow(img_tensor, cmap='gray')
plt.show()

# %%
HOG_PIXEL_PER_CELL = (4, 4)
HOG_CELL_PER_BLOCK = (2, 2)
HOG_ORIENTATIONS = 8

def get_hog_features(images_tensor):
  images_np = images_tensor.cpu().numpy()
  hog_features = []

  for image in images_np:
    image = image.reshape(28, 28)
    fd = hog(image,
             orientations=HOG_ORIENTATIONS,
             pixels_per_cell=HOG_PIXEL_PER_CELL,
             cells_per_block=HOG_CELL_PER_BLOCK, visualize=False)

    hog_features.append(fd)

  return torch.tensor(np.array(hog_features), dtype=torch.float32).to(DEVICE)

def calculate_hog_size(image_shape=(28, 28)):
  dummy_img = np.zeros(image_shape)
  fd = hog(dummy_img,
           orientations=HOG_ORIENTATIONS,
           pixels_per_cell=HOG_PIXEL_PER_CELL,
           cells_per_block=HOG_CELL_PER_BLOCK)

  return len(fd)

def apply_augmentation(images_tensor):

  images = images_tensor.view(-1, 1, 28, 28)
  augmented_image = []
  for i in range(images.shape[0]):
    img = images[i]

    angle = random.uniform(-15, 15)
    img = TF.rotate(img, angle)

    shift_x, shift_y = np.random.randint(-2,2), np.random.randint(-2,2)
    img = TF.affine(img, angle=0, translate=(shift_x, shift_y), scale=1.0, shear=0)

    augmented_image.append(img)

    images[i] = img

  return torch.stack(augmented_image).view(-1, 784)

# %%
# class WideMLP(nn.Module):
#   def __init__(self, input_size=784, num_class=15):
#     super(WideMLP, self).__init__()
#     self.fc1 = nn.Linear(input_size, 1048)
#     self.fc2 = nn.Linear(1048, 1048)
#     self.fc3 = nn.Linear(1048, num_class)

#   def forward(self, x):
#     x0 = x.view(-1, 784)
#     x1 = F.relu(self.fc1(x0))
#     x2 = F.relu(self.fc2(x1))
#     y_hat = self.fc3(x2)
#     return y_hat

# def count_parameters(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
class DeepMLP(nn.Module):
  def __init__(self, input_size=784, num_class=15):
    super(DeepMLP, self).__init__()
    self.input_size = input_size
    self.num_class = num_class
    self.fc1 = nn.Linear(self.input_size, 512)
    self.bn1 = nn.BatchNorm1d(512)

    self.fc2 = nn.Linear(512, 256)
    self.bn2 = nn.BatchNorm1d(256)

    self.fc3 = nn.Linear(256, 128)
    self.bn3 = nn.BatchNorm1d(128)

    self.fc4 = nn.Linear(128, 64)
    self.bn4 = nn.BatchNorm1d(64)

    self.fc5 = nn.Linear(64, self.num_class)

    self.drop_light = nn.Dropout(0.2)
    self.drop_heavy = nn.Dropout(0.4)

  def forward(self, x):
    x = F.gelu(self.bn1(self.fc1(x)))
    x = self.drop_heavy(F.gelu(self.bn2(self.fc2(x))))
    x = self.drop_light(F.gelu(self.bn3(self.fc3(x))))
    x = F.gelu(self.bn4(self.fc4(x)))
    y_hat = self.fc5(x)
    return y_hat

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def get_gradients_norm(model):
    grad_norms = {}
    for name, p in model.named_parameters():
        if p.grad is not None:
            grad_norms[name] = p.grad.detach().data.norm(2).item()

    return grad_norms

# %%
def train_one_epoch(model, train_data, criterion, optimizer, grad_history=None):
    
    model.train()
    total_loss, accurate_predictions, sample_count = 0.0, 0, 0
    
    for images, labels in train_data:
      images = images.to(DEVICE)
      labels = labels.to(DEVICE)

      aug_images = apply_augmentation(images)
      hog_features = get_hog_features(aug_images)

      flat_aug = aug_images.view(-1, 784)
      images = torch.cat((flat_aug, hog_features), dim=1)

      optimizer.zero_grad()
      
      outputs = model(images)
      loss = criterion(outputs, labels)
      loss.backward()

      norms = get_gradients_norm(model)
      for name, norm in norms.items():
          grad_history[name].append(norm)

      optimizer.step()

      total_loss += loss.item() * images.size(0)
      _, predicted_classes = torch.max(outputs.data, 1)
      accurate_predictions += (predicted_classes == labels).sum().item()
      sample_count += images.size(0)

    avg_loss = total_loss / sample_count
    accuracy =  100 * accurate_predictions / sample_count

    return avg_loss, accuracy

def evaluate(model, loader, criterion):
    
    model.eval()
    total_loss, accurate_predictions, sample_count = 0.0, 0, 0
    
    with torch.no_grad():
        
      for images, labels in loader:
          images = images.to(DEVICE)
          labels = labels.to(DEVICE)

          hog_features = get_hog_features(images)
          flat_images = images.view(-1, 784)
          images = torch.cat((flat_images, hog_features), dim=1)

          outputs = model(images)
          loss = criterion(outputs, labels)

          _, predicted_classes = torch.max(outputs, 1)

          accurate_predictions += (predicted_classes == labels).sum().item()
          total_loss += loss.item() * images.size(0)
          sample_count += images.size(0)

    avg_loss = total_loss / sample_count
    accuracy =  100 * accurate_predictions / sample_count

    return avg_loss, accuracy

# %%
import seaborn as sns

def confusion_matrix(model, loader):
  model.eval()
  all_preds, all_labels = [], []

  with torch.no_grad():
      for images, labels in val_loader:
          images = images.to(DEVICE)
          labels = labels.to(DEVICE)
          hog_features = get_hog_features(images)
          flat_images = images.view(-1, 784)
          images = torch.cat((flat_images, hog_features), dim=1)

          outputs = model(images.to(DEVICE))
          all_preds.extend(outputs.argmax(1).cpu().numpy())
          all_labels.extend(labels.numpy())

  cm = confusion_matrix(all_labels, all_preds)
  plt.figure(figsize=(10,8))
  sns.heatmap(cm, annot=True, fmt='d')
  plt.xlabel('Predicted')
  plt.ylabel('Actual')
  plt.show()

# %%
import copy
from sklearn.metrics import confusion_matrix
import seaborn as sns
best_model_weights = None

def train_model(model:nn.Module, epochs = 40, learning_rate=0.001, weight_decay=1e-3, grad_history=None):
  print(f"Training model for {epochs} epochs")
  print(f"Learning rate: {learning_rate}")
  print(f"Weight Decay: {weight_decay}")


  best_val_loss = float('inf')
  train_losses, train_accs, val_losses, val_accs = [], [], [], []

  criterion_cel = nn.CrossEntropyLoss(label_smoothing=0.1)

  optimizer_adam = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

  scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer_adam, mode='min', factor=0.5, patience=5, threshold=1e-4)

  for epoch in range(0, epochs):
    train_loss, train_acc = train_one_epoch(model=model,
                                            train_data=train_loader,
                                            criterion=criterion_cel,
                                            optimizer=optimizer_adam,
                                            grad_history=grad_history)

    val_loss, val_acc = evaluate(model, val_loader, criterion=criterion_cel)

    if val_loss < best_val_loss:
      best_val_loss = val_loss
      best_model_weights = copy.deepcopy(model.state_dict())
      torch.save(best_model_weights, SAVE_PATH)
      print(f"---> Best model updated at Epoch: {epoch+1} (Validation Loss: {val_loss:.4f})")

    train_losses.append(train_loss)
    train_accs.append(train_acc)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    current_learning_rate = optimizer_adam.param_groups[0]['lr']

    print(f"Epoch: {epoch+1} (Learning Rate: {current_learning_rate:.6f})")

    scheduler.step(val_loss)
    print(f"Epoch: {epoch+1}) Training Loss: {train_loss:.4f} Training Accuracy: {train_acc:.2f}% Validation Loss {val_loss:.2f}% Validaion Accuracy:{val_acc:.2f}%")

  model.load_state_dict(best_model_weights)
  torch.save(model.state_dict(), SAVE_PATH)
  print("Training complete. Loaded best model weights")
  print(best_model_weights)
  print(f"Best model saved at {SAVE_PATH}")
  confusion_matrix(model, val_loader)

  return train_losses, train_accs, val_losses, val_accs

# %%
# # Initialize Wide model
# wide_model = WideMLP().to(DEVICE)
# print(f"WideMLP Parameters: {count_parameters(wide_model)}")

# EPOCHS = 20
# LEARNING_RATE = 0.0005
# L2_REGULARIZATION = 1e-3
# train_losses, train_acc, val_losses, val_acc = train_model(wide_model, epochs=EPOCHS, learning_rate=L2_REGULARIZATION)

# plt.figure(figsize=(15, 5))
# plt.subplot(1, 2, 1)
# plt.plot(train_losses, label='Training Loss', color='#1f77b4')
# plt.plot(val_losses, label='Validation Loss', color='#1f7f0e')
# plt.title('Wide MLP Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()

# plt.subplot(1, 2, 2)
# plt.plot(train_acc, label='Training Acc', color='#1f77b4')
# plt.plot(val_acc, label='Validation Acc', color='#1f7f0e')
# plt.title('Wide MLP Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
# Initialize Wide model
# Initialize model

input_size = calculate_hog_size() + 784
print(input_size)
deep_model = DeepMLP(input_size).to(DEVICE)
print(f"DeepMLP Parameters: {count_parameters(deep_model)}")

EPOCHS = 35
LEARNING_RATE = 0.001
L2_REGULARIZATION = 1e-4
WEIGHT_DECAY = 1e-3
grad_history = {name:[] for name, _ in deep_model.named_parameters()}
train_losses, train_acc, val_losses, val_acc = train_model(deep_model, epochs=EPOCHS, learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY, grad_history=grad_history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss', color='#1f77b4')
plt.plot(val_losses, label='Validation Loss', color='#1f7f0e')
plt.title('Deep MLP Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Acc', color='#1f77b4')
plt.plot(val_acc, label='Validation Acc', color='#1f7f0e')
plt.title('Deep MLP Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1936
# DeepMLP Parameters: 1167119
# Training model for 35 epochs
# Learning rate: 0.001
# Weight Decay: 0.001
# ---> Best model updated at Epoch: 1 (Validation Loss: 1.1250)
# Epoch: 1 (Learning Rate: 0.001000)
# Epoch: 1) Training Loss: 1.4132 Training Accuracy: 65.45% Validation Loss 1.13% Validaion Accuracy:77.47%
# ---> Best model updated at Epoch: 2 (Validation Loss: 1.0873)
# Epoch: 2 (Learning Rate: 0.001000)
# Epoch: 2) Training Loss: 1.2754 Training Accuracy: 70.55% Validation Loss 1.09% Validaion Accuracy:77.88%
# Epoch: 3 (Learning Rate: 0.001000)
# Epoch: 3) Training Loss: 1.2474 Training Accuracy: 72.00% Validation Loss 1.10% Validaion Accuracy:78.45%
# ---> Best model updated at Epoch: 4 (Validation Loss: 1.0550)
# Epoch: 4 (Learning Rate: 0.001000)
# Epoch: 4) Training Loss: 1.2247 Training Accuracy: 72.95% Validation Loss 1.05% Validaion Accuracy:80.15%
# Epoch: 5 (Learning Rate: 0.001000)
# Epoch: 5) Training Loss: 1.2087 Training Accuracy: 73.63% Validation Loss 1.06% Validaion Accuracy:79.49%
# ---> Best model updated at Epoch: 6 (Validation Loss: 1.0489)
# Epoch: 6 (Learning Rate: 0.001000)
# Epoch: 6) Training Loss: 1.1929 Training Accuracy: 74.21% Validation Loss 1.05% Validaion Accuracy:80.56%
# ---> Best model updated at Epoch: 7 (Validation Loss: 1.0349)
# Epoch: 7 (Learning Rate: 0.001000)
# Epoch: 7) Training Loss: 1.1883 Training Accuracy: 74.71% Validation Loss 1.03% Validaion Accuracy:81.21%
# ---> Best model updated at Epoch: 8 (Validation Loss: 1.0255)
# Epoch: 8 (Learning Rate: 0.001000)
# Epoch: 8) Training Loss: 1.1812 Training Accuracy: 74.73% Validation Loss 1.03% Validaion Accuracy:81.68%
# Epoch: 9 (Learning Rate: 0.001000)
# Epoch: 9) Training Loss: 1.1766 Training Accuracy: 75.10% Validation Loss 1.03% Validaion Accuracy:81.21%
# Epoch: 10 (Learning Rate: 0.001000)
# Epoch: 10) Training Loss: 1.1747 Training Accuracy: 75.35% Validation Loss 1.03% Validaion Accuracy:81.37%
# Epoch: 11 (Learning Rate: 0.001000)
# Epoch: 11) Training Loss: 1.1764 Training Accuracy: 74.84% Validation Loss 1.03% Validaion Accuracy:81.29%
# ---> Best model updated at Epoch: 12 (Validation Loss: 1.0245)
# Epoch: 12 (Learning Rate: 0.001000)
# Epoch: 12) Training Loss: 1.1747 Training Accuracy: 75.20% Validation Loss 1.02% Validaion Accuracy:81.51%
# Epoch: 13 (Learning Rate: 0.001000)
# Epoch: 13) Training Loss: 1.1726 Training Accuracy: 75.22% Validation Loss 1.03% Validaion Accuracy:81.17%
# ---> Best model updated at Epoch: 14 (Validation Loss: 1.0241)
# Epoch: 14 (Learning Rate: 0.001000)
# Epoch: 14) Training Loss: 1.1724 Training Accuracy: 75.32% Validation Loss 1.02% Validaion Accuracy:81.54%
# ---> Best model updated at Epoch: 15 (Validation Loss: 1.0191)
# Epoch: 15 (Learning Rate: 0.001000)
# Epoch: 15) Training Loss: 1.1668 Training Accuracy: 75.65% Validation Loss 1.02% Validaion Accuracy:81.76%
# Epoch: 16 (Learning Rate: 0.001000)
# Epoch: 16) Training Loss: 1.1658 Training Accuracy: 75.91% Validation Loss 1.03% Validaion Accuracy:81.33%
# Epoch: 17 (Learning Rate: 0.001000)
# Epoch: 17) Training Loss: 1.1630 Training Accuracy: 75.75% Validation Loss 1.02% Validaion Accuracy:81.55%
# Epoch: 18 (Learning Rate: 0.001000)
# Epoch: 18) Training Loss: 1.1637 Training Accuracy: 76.05% Validation Loss 1.02% Validaion Accuracy:81.89%
# Epoch: 19 (Learning Rate: 0.001000)
# Epoch: 19) Training Loss: 1.1644 Training Accuracy: 75.74% Validation Loss 1.03% Validaion Accuracy:81.12%
# Epoch: 20 (Learning Rate: 0.001000)
# Epoch: 20) Training Loss: 1.1610 Training Accuracy: 75.89% Validation Loss 1.02% Validaion Accuracy:81.75%
# ---> Best model updated at Epoch: 21 (Validation Loss: 1.0180)
# Epoch: 21 (Learning Rate: 0.001000)
# Epoch: 21) Training Loss: 1.1618 Training Accuracy: 75.79% Validation Loss 1.02% Validaion Accuracy:81.53%
# Epoch: 22 (Learning Rate: 0.001000)
# Epoch: 22) Training Loss: 1.1599 Training Accuracy: 75.94% Validation Loss 1.05% Validaion Accuracy:79.97%
# ---> Best model updated at Epoch: 23 (Validation Loss: 1.0161)
# Epoch: 23 (Learning Rate: 0.001000)
# Epoch: 23) Training Loss: 1.1618 Training Accuracy: 75.92% Validation Loss 1.02% Validaion Accuracy:81.83%
# Epoch: 24 (Learning Rate: 0.001000)
# Epoch: 24) Training Loss: 1.1557 Training Accuracy: 76.18% Validation Loss 1.02% Validaion Accuracy:81.61%
# Epoch: 25 (Learning Rate: 0.001000)
# Epoch: 25) Training Loss: 1.1598 Training Accuracy: 76.09% Validation Loss 1.02% Validaion Accuracy:81.83%
# Epoch: 26 (Learning Rate: 0.001000)
# Epoch: 26) Training Loss: 1.1589 Training Accuracy: 76.04% Validation Loss 1.02% Validaion Accuracy:81.21%
# Epoch: 27 (Learning Rate: 0.001000)
# Epoch: 27) Training Loss: 1.1578 Training Accuracy: 76.14% Validation Loss 1.02% Validaion Accuracy:81.76%
# ---> Best model updated at Epoch: 28 (Validation Loss: 1.0075)
# Epoch: 28 (Learning Rate: 0.001000)
# Epoch: 28) Training Loss: 1.1554 Training Accuracy: 76.07% Validation Loss 1.01% Validaion Accuracy:82.15%
# Epoch: 29 (Learning Rate: 0.001000)
# Epoch: 29) Training Loss: 1.1540 Training Accuracy: 76.17% Validation Loss 1.02% Validaion Accuracy:81.51%
# Epoch: 30 (Learning Rate: 0.001000)
# Epoch: 30) Training Loss: 1.1592 Training Accuracy: 76.06% Validation Loss 1.02% Validaion Accuracy:81.58%
# Epoch: 31 (Learning Rate: 0.001000)
# Epoch: 31) Training Loss: 1.1576 Training Accuracy: 75.90% Validation Loss 1.01% Validaion Accuracy:82.04%
# Epoch: 32 (Learning Rate: 0.001000)
# Epoch: 32) Training Loss: 1.1588 Training Accuracy: 75.86% Validation Loss 1.02% Validaion Accuracy:81.29%
# Epoch: 33 (Learning Rate: 0.001000)
# Epoch: 33) Training Loss: 1.1545 Training Accuracy: 76.03% Validation Loss 1.02% Validaion Accuracy:81.61%
# Epoch: 34 (Learning Rate: 0.001000)
# Epoch: 34) Training Loss: 1.1525 Training Accuracy: 76.10% Validation Loss 1.01% Validaion Accuracy:81.74%
# ---> Best model updated at Epoch: 35 (Validation Loss: 0.9897)
# Epoch: 35 (Learning Rate: 0.000500)
# Epoch: 35) Training Loss: 1.1182 Training Accuracy: 77.83% Validation Loss 0.99% Validaion Accuracy:83.12%
# Training complete. Loaded best model weights
# OrderedDict({'fc1.weight': tensor([[-1.1029e-35,  2.1943e-40, -3.5716e-40,  ...,  5.3216e-40,
#          -2.2182e-40, -2.4994e-37],
#         [-3.7000e-32, -7.0115e-31,  3.2133e-40,  ..., -1.0403e-32,
#           1.6165e-40, -3.8125e-40],
#         [ 1.2408e-03,  6.5223e-03,  4.1694e-03,  ..., -2.5890e-03,
#           1.6223e-03, -1.3486e-02],
#         ...,
#         [-3.8508e-28, -4.7373e-40, -2.9472e-41,  ..., -3.7754e-41,
#           4.5274e-40,  5.6684e-40],
#         [ 3.8715e-35, -4.7908e-34,  1.8448e-38,  ..., -8.1313e-38,
#           1.7125e-38, -2.2466e-38],
#         [ 6.7650e-40, -3.2964e-41,  2.9447e-40,  ...,  5.8467e-31,
#          -5.2227e-35,  1.9639e-29]]), 'fc1.bias': tensor([-3.9519e-37, -3.8509e-37, -1.3735e-05, -3.2696e-25,  1.1035e-05,
#          1.8066e-36,  1.2279e-32, -4.7074e-36, -2.6518e-33, -1.0000e-34,
#         -1.5118e-27,  1.6647e-29, -5.9818e-34, -7.1457e-29,  3.2689e-33,
#          1.8339e-31, -3.7367e-33, -4.2261e-06,  1.0151e-11,  2.6166e-35,
#          3.8136e-35, -7.7074e-30, -3.6605e-30, -8.4683e-34,  8.9913e-38,
#          1.1757e-11,  4.3651e-29, -3.0103e-32, -5.9616e-38, -1.8217e-34,
#          1.2561e-28,  7.1136e-30, -1.2309e-31, -2.0738e-34, -9.7573e-29,
#          1.2346e-05, -1.7995e-27,  8.1088e-36, -2.8271e-36, -8.6782e-09,
#         -8.9199e-07, -6.4565e-37, -7.5093e-29,  6.3219e-06, -1.3485e-28,
#          2.1396e-37,  1.2878e-07, -4.1142e-37, -5.4474e-36,  1.5700e-30,
#          2.7587e-30,  1.8038e-27,  1.7657e-05, -2.1511e-36, -1.1252e-28,
#          6.7190e-06, -8.3478e-28, -8.3938e-30, -7.7054e-07, -2.7925e-32,
#         -3.3981e-33,  1.5371e-06,  8.1029e-37,  9.1216e-34,  3.2716e-29,
#         -6.0348e-06, -4.0763e-06, -3.6337e-31,  1.6110e-05, -1.4988e-31,
#         -1.3467e-28, -3.4384e-34,  5.9607e-34,  7.2491e-34, -1.0275e-30,
#          9.6790e-29,  5.6163e-30,  3.5059e-35, -5.0441e-30, -4.8828e-06,
#          7.8326e-36,  6.1000e-31,  4.0576e-06, -6.3465e-34, -3.3559e-36,
#         -7.7200e-06, -1.6113e-37, -6.9515e-36,  2.3158e-32, -1.9290e-07,
#         -1.9065e-36,  9.8259e-06,  1.7832e-29, -5.4353e-29,  8.8024e-36,
#         -6.7943e-32, -4.5943e-07, -9.2478e-37,  8.3008e-06,  8.5645e-38,
#         -1.9488e-35, -3.8751e-32,  6.3095e-33, -1.1634e-29,  7.9114e-09,
#         -5.2704e-36, -5.2564e-36, -9.6498e-33, -6.0897e-34, -3.9686e-36,
#          1.1691e-31, -4.1716e-37,  7.4173e-06, -2.0395e-34,  4.1783e-28,
#          8.7013e-37, -1.7819e-30,  2.2186e-36, -1.4706e-29,  1.3951e-30,
#         -5.1329e-28, -8.4000e-32,  2.2033e-05,  7.2046e-07,  2.3709e-31,
#         -2.5118e-31, -6.3824e-35, -2.0616e-05, -2.5506e-11,  4.0461e-06,
#          5.3202e-30,  8.6309e-35,  7.3470e-28, -2.5459e-28,  4.8425e-32,
#          2.6426e-32,  3.7796e-22,  2.7721e-36,  2.4591e-31, -1.9537e-35,
#          6.7174e-35, -3.0396e-28, -6.1137e-32, -1.1000e-32,  1.1022e-05,
#          1.3421e-30,  1.5860e-05, -4.5932e-34, -3.9274e-10, -8.2436e-28,
#         -6.2247e-08,  2.7226e-28, -3.4248e-32, -1.2997e-09,  2.4107e-39,
#         -3.4507e-33, -5.6233e-37, -1.3533e-35,  2.3010e-34, -1.2165e-36,
#          5.5451e-28, -1.5224e-28, -4.4184e-35, -3.7336e-34, -1.5945e-33,
#          1.0486e-10,  1.4060e-36, -2.7390e-07, -3.7917e-33, -2.6371e-30,
#         -1.8058e-36, -2.7615e-37, -3.0753e-33, -6.7409e-32,  1.5531e-34,
#         -6.9628e-30, -3.9903e-30,  5.1464e-30,  1.0458e-29,  7.1873e-29,
#         -4.6612e-32, -7.7629e-14, -7.9443e-29,  1.8262e-28, -2.6412e-30,
#          9.2256e-06,  2.4354e-33, -1.6545e-36, -7.4591e-35,  4.4744e-36,
#         -1.1471e-32, -1.7753e-29,  1.1270e-10,  2.6782e-37,  3.4935e-34,
#         -4.7895e-33, -9.7877e-37,  9.6411e-29,  1.0230e-36, -4.1133e-35,
#         -1.4919e-28,  1.0969e-31,  5.9262e-32, -3.4904e-30, -5.9953e-37,
#          8.1525e-06,  5.6144e-30,  5.9733e-30,  3.5455e-06,  1.0077e-31,
#         -4.5685e-35, -2.0401e-31,  1.5016e-28, -1.4469e-32,  1.9328e-27,
#          2.9074e-06,  4.3253e-31, -1.9467e-09,  5.6761e-30, -6.7287e-11,
#          2.1654e-36, -3.3198e-29, -2.2408e-34, -8.7629e-06, -1.1694e-06,
#          4.9239e-29, -2.0150e-37, -8.4088e-14,  1.2987e-35, -1.7135e-05,
#          1.0563e-31, -2.7043e-33,  1.4115e-36,  1.6806e-36,  1.7985e-36,
#         -1.7621e-29, -7.6347e-33,  1.0393e-33,  4.9695e-33, -5.3540e-29,
#          1.2478e-34,  7.5964e-32,  1.1694e-33, -7.7304e-20, -7.9519e-35,
#          6.8670e-33,  1.0723e-31,  1.3122e-28, -5.4271e-37, -1.1491e-37,
#          8.9503e-34,  3.5278e-35,  2.7112e-36,  1.8347e-11, -3.8790e-14,
#         -3.6942e-12, -8.4945e-29, -1.5144e-30,  9.8716e-38,  2.4918e-28,
#         -4.4502e-34,  3.6946e-37,  1.6413e-06, -1.4654e-33,  1.8069e-28,
#         -3.6091e-32,  4.9549e-37, -1.4481e-31, -7.4881e-38,  9.8399e-07,
#         -2.5991e-31, -1.6011e-08, -9.7810e-28, -7.7513e-37,  1.1094e-27,
#         -2.2671e-31,  2.3117e-39, -2.0465e-33,  5.7145e-33, -9.7096e-37,
#          2.3416e-33, -2.2923e-34, -1.7369e-31, -4.2107e-35,  2.0388e-05,
#         -5.3447e-32,  3.5862e-09,  1.6190e-31, -6.4084e-26,  8.2408e-38,
#         -1.6543e-27, -5.5786e-32,  1.0878e-30,  1.0311e-36,  2.6152e-32,
#         -3.1200e-26,  4.7232e-37, -1.4621e-35,  7.4923e-35, -3.1567e-28,
#         -1.2987e-35,  1.0558e-38, -3.9186e-32, -1.3997e-35, -4.8342e-32,
#         -1.4906e-08,  1.7413e-32, -1.7318e-08, -2.2918e-31,  8.0527e-30,
#         -8.1635e-31, -1.4204e-36, -3.0084e-06,  4.1739e-28, -7.9259e-32,
#          2.7768e-30,  1.5024e-30,  4.6251e-35, -1.0032e-32,  5.2901e-37,
#          3.0901e-32,  2.1613e-37, -1.4303e-36,  1.0561e-33, -1.0960e-05,
#         -1.7784e-34,  3.9786e-36, -3.1915e-28, -7.0098e-35,  3.0547e-33,
#         -1.3346e-28, -1.9308e-35,  7.8869e-30, -2.8810e-30,  9.4851e-29,
#         -1.9110e-31, -1.2261e-28, -2.8502e-29,  1.9838e-28, -4.0199e-29,
#         -5.1623e-35,  2.0911e-36,  1.0962e-05,  5.2401e-35,  1.8848e-06,
#         -3.4561e-33, -9.7968e-32,  2.8898e-31, -3.3412e-30,  2.0170e-31,
#          1.1023e-29,  9.8131e-30, -7.7721e-20, -3.0433e-36, -2.2453e-36,
#          7.7222e-31, -2.3472e-37,  4.0618e-34, -2.3965e-08, -3.4203e-33,
#         -3.8942e-35, -2.1958e-29,  4.8074e-30, -1.0165e-27, -5.6134e-34,
#         -2.3433e-32, -6.4671e-32,  2.5541e-37,  3.9778e-07,  2.0199e-31,
#         -3.5070e-30,  6.0610e-37, -1.6534e-31,  2.6930e-37, -5.4491e-37,
#          1.2859e-36, -1.0310e-05, -1.1158e-30,  3.4666e-36, -1.1865e-05,
#         -2.8996e-31,  2.7379e-05, -1.0311e-32,  7.0150e-32,  1.9529e-36,
#          1.2111e-34,  1.1872e-36, -3.1354e-30,  9.0356e-35,  4.1846e-06,
#         -2.8324e-06, -5.0451e-29, -6.9445e-33, -2.3410e-37, -1.2141e-05,
#          8.6518e-36,  1.1196e-31,  1.9524e-33,  4.3707e-30, -2.0297e-37,
#          4.5378e-11,  1.0349e-33, -5.9769e-29,  5.3637e-34,  1.8729e-32,
#          2.4144e-35, -4.9291e-36, -4.1862e-35, -4.2224e-36,  2.0803e-06,
#          1.7771e-37,  9.8478e-36,  5.6931e-38,  3.0010e-34, -7.2657e-36,
#          1.7062e-34, -1.9677e-05,  1.1750e-30, -9.6341e-06, -6.8398e-37,
#          2.1351e-33, -1.5590e-36, -8.2329e-33,  1.3630e-29, -9.6406e-28,
#          4.0421e-10,  2.1305e-34,  1.6649e-29,  6.1625e-32, -3.3135e-29,
#         -1.7009e-34,  2.0211e-05,  3.5570e-30,  2.0947e-35,  7.2886e-33,
#          2.5500e-36,  1.4793e-35, -3.3222e-29, -1.2110e-28,  2.9387e-06,
#         -3.6543e-34,  4.2537e-30,  9.9803e-06, -5.2216e-36,  2.4670e-34,
#          7.8975e-30, -3.2258e-28, -3.5706e-32, -7.1256e-36,  1.2263e-31,
#          7.7012e-38, -5.6992e-28, -4.5466e-06, -1.6009e-32,  1.2328e-36,
#          1.2126e-35,  6.7207e-33,  5.2334e-31,  5.8088e-07,  9.1563e-14,
#         -8.2545e-35, -1.8134e-28, -3.5891e-35, -7.7078e-31,  8.0380e-29,
#         -3.9003e-06, -2.3836e-29, -2.0290e-30,  3.5745e-09, -3.1780e-33,
#          2.1676e-27, -9.9518e-38,  9.7623e-06, -1.9231e-34, -6.0484e-37,
#          4.8545e-12,  4.9718e-35,  7.2286e-29,  2.4356e-34,  1.0642e-28,
#          1.4074e-33, -4.2476e-36,  2.6931e-06, -6.8726e-09, -4.5475e-31,
#          3.4082e-30, -4.8056e-30,  3.4062e-37, -1.2382e-34, -1.7035e-33,
#          1.7882e-35,  2.5435e-30,  2.0425e-37, -3.3266e-30,  6.3062e-35,
#          2.5102e-35, -2.0949e-36, -1.9893e-33, -2.0805e-34, -7.4140e-31,
#          6.7426e-33,  6.8158e-06,  7.1426e-34,  6.2431e-31,  6.9019e-28,
#          1.4830e-36, -6.8111e-32, -6.7762e-29,  5.7975e-37, -1.9075e-33,
#         -8.5815e-38,  3.2549e-28]), 'bn1.weight': tensor([ 2.1271e-40,  2.3016e-40,  4.4868e-01,  3.1733e-06,  5.5213e-01,
#          3.7129e-41, -5.9719e-41,  3.6371e-40,  6.0597e-40,  4.1192e-40,
#         -4.8722e-41,  3.2176e-40,  2.2244e-40,  2.4286e-40,  8.3033e-14,
#         -1.3038e-40,  3.7039e-40,  3.7836e-01,  6.5456e-06,  1.1117e-41,
#          1.8709e-40, -3.4552e-14,  1.5092e-40,  6.3523e-40,  1.8862e-40,
#         -3.2538e-06, -1.5943e-40,  3.7877e-40,  2.6066e-40,  4.9520e-40,
#         -3.6975e-12,  3.3270e-40, -2.7603e-40, -5.6828e-41,  2.8296e-40,
#          3.8501e-01, -1.1742e-40,  4.4320e-40,  1.7324e-40, -1.4374e-04,
#          4.5530e-01,  3.7115e-41, -7.9139e-07,  4.1320e-01,  1.2098e-40,
#          4.5296e-40,  4.0401e-01, -1.6987e-11,  5.9851e-41,  3.5256e-40,
#          2.6444e-40,  4.0677e-40,  4.7924e-01, -2.2665e-07,  2.7131e-40,
#          3.6980e-01,  2.9929e-40,  2.3595e-40,  3.8236e-01,  4.2362e-40,
#          2.6512e-40,  3.5876e-01,  2.1608e-40,  6.2075e-41,  1.5413e-41,
#          4.2746e-01,  4.2888e-01,  7.2771e-07,  6.0106e-01,  2.0193e-40,
#          1.0237e-40,  2.9759e-41,  4.7682e-40,  3.5979e-40,  2.8323e-40,
#          4.3734e-40,  3.7503e-40,  2.7239e-40, -1.3545e-41,  4.6607e-01,
#         -3.9711e-41,  8.5288e-13,  4.2046e-01,  2.9306e-40,  4.4589e-40,
#          4.0552e-01, -1.3470e-40,  1.3866e-40, -1.6986e-40,  4.5162e-01,
#          2.7965e-40,  4.4331e-01,  3.1236e-40,  4.2228e-40, -2.1279e-41,
#         -1.1033e-40,  4.1724e-01,  3.3817e-08,  4.1297e-01,  3.3298e-40,
#          1.7701e-40,  3.0668e-40,  4.1710e-40,  3.4566e-40, -1.6120e-04,
#          4.3966e-41,  3.1591e-40, -3.7141e-41,  2.0788e-40, -4.6341e-42,
#          2.7595e-40,  2.1925e-40,  4.9690e-01,  2.2659e-40,  2.6154e-40,
#          4.0085e-40,  5.2409e-40,  3.5021e-40, -1.7518e-07, -2.4218e-18,
#         -9.5891e-42,  4.6316e-40,  4.8077e-01,  3.6515e-01,  2.7488e-40,
#          4.1924e-40,  5.4070e-40,  4.7110e-01,  5.0454e-06,  3.9994e-01,
#          2.9495e-40,  5.7267e-41, -1.6154e-40,  1.0049e-40,  3.5090e-41,
#          2.4032e-40,  1.7754e-06,  3.5942e-40,  4.2472e-40, -3.9262e-41,
#          4.8307e-37,  3.0921e-40,  3.2740e-40,  2.7337e-40,  4.3092e-01,
#          3.8019e-40,  4.7168e-01,  2.6696e-40, -4.6895e-04,  2.4520e-40,
#          1.4626e-03,  2.7958e-40,  1.2077e-40,  7.9680e-05,  6.4207e-40,
#          1.5273e-40,  1.1589e-40,  2.8411e-40,  2.9596e-40, -2.1992e-12,
#         -8.7696e-19,  3.3993e-40,  2.8197e-40,  6.9148e-41,  1.4680e-40,
#         -2.8052e-04,  2.2196e-40,  4.8457e-01,  1.2363e-40,  5.8919e-40,
#          3.0650e-40,  2.1646e-40,  4.8931e-40,  4.6318e-40,  4.8397e-40,
#          2.1685e-40,  1.6505e-40,  4.8449e-40, -1.9519e-16, -1.6046e-41,
#          2.3619e-40, -1.9056e-05,  1.5300e-16, -4.3564e-41,  4.0293e-40,
#          4.8112e-01, -7.0431e-16,  7.5405e-41,  1.6282e-40, -8.9462e-41,
#          2.4606e-40, -3.1876e-40,  1.3786e-05,  2.9102e-40,  7.7087e-41,
#          7.2577e-41, -8.5816e-42,  5.7559e-40,  4.0370e-09,  3.6957e-40,
#          1.6816e-40, -7.4496e-41,  2.5111e-40,  2.7452e-40,  3.0179e-40,
#          4.5301e-01,  2.3793e-40,  2.0683e-40,  4.1601e-01,  3.6218e-40,
#          4.6606e-40,  4.3324e-40,  4.1968e-40,  3.1344e-40, -5.2911e-07,
#          4.5678e-01,  1.0842e-40,  1.6922e-04, -1.6487e-40, -2.8309e-05,
#         -1.2087e-40,  3.1109e-43,  3.1531e-09,  6.2500e-01,  4.2717e-01,
#          2.4764e-40,  3.3701e-40,  2.2739e-05,  1.3031e-40,  4.2116e-01,
#          3.6674e-40,  3.5704e-13, -3.4314e-16,  2.9880e-40,  1.2798e-40,
#          1.8716e-40,  4.2086e-40,  3.3511e-40,  1.9017e-41,  2.0153e-40,
#          4.6540e-40,  3.4210e-40,  4.3452e-40, -2.8421e-06,  2.4027e-40,
#          2.7931e-40,  2.6482e-40, -3.9745e-41,  1.0000e-40,  4.0137e-40,
#         -1.6471e-13,  2.4744e-40,  6.2403e-41,  4.6487e-06, -9.8209e-06,
#         -3.0161e-06,  4.2683e-40,  2.1726e-40, -1.6171e-10, -1.1890e-40,
#         -7.3372e-41,  1.6533e-40,  6.7747e-01,  1.1688e-17,  2.2143e-40,
#          3.1828e-40, -1.1099e-17,  1.5855e-07,  3.6228e-40,  4.2069e-01,
#          1.1184e-41, -1.6297e-04,  1.2486e-40,  2.7163e-40,  1.7221e-12,
#          3.7312e-40,  2.5995e-40,  3.7226e-40,  7.8563e-14,  6.3216e-40,
#          4.6723e-41, -2.4677e-41,  5.5909e-40,  5.1731e-40,  3.7644e-01,
#          4.8914e-40,  6.5505e-04,  3.9588e-40, -2.7898e-07,  3.6095e-40,
#          2.9517e-40,  2.6308e-40, -1.2109e-41,  2.4912e-40, -1.6851e-40,
#         -6.7232e-07,  2.6311e-41,  2.9979e-40,  1.5171e-40,  4.3170e-41,
#         -9.1189e-41, -1.9867e-40,  2.8357e-40, -2.5531e-40,  9.7366e-41,
#         -4.6273e-04,  1.2839e-40, -5.3205e-04, -1.0049e-07,  3.1227e-40,
#          2.0478e-40, -1.5912e-40,  5.2190e-01,  2.3208e-40,  2.8294e-40,
#          3.2706e-40,  2.7219e-40,  2.1748e-41,  7.8682e-41,  6.4406e-41,
#         -7.0308e-14, -1.3303e-40, -2.2053e-40,  2.4560e-40,  4.3420e-01,
#          3.3450e-40,  2.8986e-40,  2.9398e-40,  1.5556e-40,  3.7763e-40,
#          5.8216e-40,  5.7883e-40,  4.5152e-40,  2.4084e-41,  2.3875e-40,
#          4.5129e-40, -2.5616e-13,  5.5123e-40,  2.7359e-40,  4.6287e-40,
#          2.2909e-40, -9.9966e-41,  4.5101e-01,  2.8582e-40,  3.5757e-01,
#          7.8252e-25,  1.3140e-40,  1.8544e-40,  2.4283e-40,  2.1433e-41,
#         -2.1499e-41, -1.2671e-40, -1.8862e-06,  5.2771e-40,  6.4374e-40,
#         -2.2354e-41,  3.1972e-40,  7.0100e-14,  1.0939e-03,  2.2999e-40,
#          5.2453e-41,  6.3136e-09,  3.3757e-40,  2.2933e-40,  4.1832e-40,
#          3.0480e-40,  4.4139e-40,  4.4028e-40,  3.2896e-01,  1.6144e-40,
#          4.0256e-40,  2.6621e-40,  2.0307e-40,  1.4788e-40, -1.4141e-40,
#          4.7668e-41,  4.0963e-01,  9.5531e-11,  5.6405e-40,  4.6363e-01,
#          3.9098e-40,  6.9119e-01,  1.8690e-40,  6.2925e-40,  3.9992e-40,
#         -2.1542e-40,  5.5795e-40,  2.0905e-14, -1.2479e-40,  4.1304e-01,
#          4.2826e-01,  5.3027e-40,  2.6524e-40,  3.0646e-40,  4.0649e-01,
#          1.0490e-20,  2.4346e-40, -4.3363e-16,  3.8485e-40,  2.8880e-40,
#         -1.0520e-05,  1.3827e-40,  4.7500e-40,  2.7438e-40,  3.0215e-40,
#          3.0544e-40, -1.8722e-12, -9.3890e-41, -1.3488e-40,  3.7021e-01,
#          2.8837e-40,  5.3979e-40,  8.1275e-44,  3.2989e-40,  8.8727e-41,
#         -5.7082e-41,  4.2626e-01,  3.4787e-41,  4.5461e-01,  3.4801e-40,
#          4.1380e-40,  3.4766e-40,  3.3135e-40,  1.2578e-13,  1.8919e-40,
#          2.5508e-05,  3.7823e-40,  1.0726e-40,  3.9848e-40,  1.3988e-40,
#          2.9739e-40,  5.3344e-01,  1.3141e-40,  2.7212e-40,  3.9998e-40,
#          2.4239e-40, -3.1561e-41,  1.9826e-40,  4.1383e-40,  3.8386e-01,
#          4.4011e-40, -9.6164e-18,  3.9671e-01,  2.4348e-41,  5.1045e-40,
#         -4.2883e-41,  2.4897e-40, -2.1968e-41,  2.5341e-40,  2.9883e-40,
#          2.6176e-40,  3.4385e-19,  5.8837e-01,  5.7431e-40, -1.1361e-14,
#          3.0097e-41,  9.9634e-41,  4.6303e-40,  3.4264e-01,  1.1740e-05,
#          8.3791e-41,  4.3105e-40,  3.4398e-40,  3.4230e-40, -1.1837e-40,
#          4.2161e-01,  2.2584e-40,  2.9598e-40,  1.2946e-04,  3.1495e-40,
#          4.4988e-40,  5.1911e-41,  3.6540e-01, -9.3741e-08,  1.7676e-07,
#          1.9228e-05,  4.1772e-40,  2.2182e-40,  1.4524e-40,  3.9986e-40,
#          2.3749e-40,  2.7241e-42,  4.4498e-01,  5.0433e-04,  1.6099e-40,
#          4.0202e-40,  1.6214e-40,  3.9485e-40,  4.4738e-40,  2.0683e-42,
#         -1.4029e-15,  2.8906e-40,  2.6464e-40,  3.5554e-41, -2.6081e-40,
#         -7.1588e-17,  5.1985e-40,  2.8690e-40, -3.6509e-40,  1.7683e-40,
#          2.2945e-40,  4.3338e-01,  2.8964e-40,  7.1487e-41, -1.3550e-40,
#          4.1226e-40,  3.9679e-40, -2.3462e-40,  5.3602e-14,  4.7947e-40,
#          1.4426e-40, -3.4280e-40]), 'bn1.bias': tensor([-1.0871e-40,  2.6588e-40, -6.2366e-01, -1.2997e-22, -5.5763e-01,
#          2.3264e-41, -1.6654e-40, -5.2357e-40,  1.9970e-40, -3.6209e-40,
#         -3.8246e-40,  2.2246e-41,  2.2912e-40,  2.1676e-40,  8.1707e-38,
#         -2.4004e-40,  4.3031e-40, -6.1904e-01, -1.3321e-06, -4.2639e-40,
#         -2.0102e-40, -1.0393e-35,  2.0636e-40, -5.0663e-40, -5.0486e-40,
#         -2.6879e-06, -3.1952e-40, -3.8222e-40, -2.9026e-40,  9.1662e-41,
#          1.9580e-36, -6.0718e-42, -4.1204e-40, -1.1600e-40,  8.3055e-42,
#         -6.6242e-01,  8.3097e-41, -4.2787e-41, -1.5948e-40, -2.5159e-03,
#         -6.3144e-01,  9.2501e-41, -2.7016e-26, -6.3123e-01,  9.3525e-41,
#          2.1761e-40, -6.1450e-01, -1.4749e-35,  2.0323e-40, -6.9258e-41,
#          1.0935e-40, -1.2730e-40, -6.4081e-01,  2.5419e-35,  2.2903e-41,
#         -6.1027e-01,  1.6383e-40,  4.4962e-40, -6.7945e-01, -6.1216e-40,
#          7.6418e-41, -6.8663e-01,  1.8932e-42, -5.4300e-41,  1.5227e-40,
#         -5.8005e-01, -5.0365e-01, -1.1631e-28, -2.3267e-01,  2.1681e-41,
#         -1.4030e-40,  1.3446e-40,  2.9297e-40, -4.4732e-40, -3.2661e-40,
#         -2.7013e-40, -2.1238e-40, -4.3548e-40,  1.8162e-40, -6.5734e-01,
#         -4.4800e-41, -6.2368e-37, -6.3713e-01, -1.2307e-40,  5.1198e-40,
#         -4.7543e-01,  1.1087e-40,  1.4678e-40, -2.3242e-40, -6.2977e-01,
#          2.1688e-40, -4.8424e-01, -3.2721e-40,  5.9157e-40,  8.4068e-41,
#         -1.7392e-40, -4.8185e-01, -6.0917e-39, -6.8529e-01, -4.4262e-40,
#          3.9898e-41, -1.6466e-40, -3.7943e-40, -1.6419e-40, -2.5297e-03,
#          1.8764e-40,  5.4629e-40, -1.9280e-40,  5.3350e-41,  4.7376e-40,
#          5.5439e-40, -3.2908e-40, -5.3602e-01, -1.1195e-40,  3.6299e-40,
#         -7.3512e-42, -5.7840e-41,  2.2908e-40, -2.3605e-22, -1.0990e-39,
#         -2.5775e-40,  8.5119e-41, -5.3043e-01, -6.0332e-01,  6.0130e-40,
#          4.2800e-40,  5.4126e-40, -2.3625e-01, -6.6707e-07, -6.8636e-01,
#          5.7664e-40, -4.3325e-40, -2.6840e-40,  7.4857e-41,  3.1943e-40,
#         -6.5243e-41, -7.2789e-15, -6.2400e-40, -1.5459e-40,  1.3082e-40,
#         -1.1414e-40, -3.8461e-40,  6.0496e-40, -3.5429e-40, -4.3620e-01,
#         -4.2650e-40, -5.8997e-01, -7.5430e-41, -3.4303e-03, -1.4784e-40,
#         -9.7502e-03,  1.2208e-40, -2.9261e-40, -2.9648e-06,  3.2888e-41,
#         -2.8018e-40,  3.2645e-40,  4.2650e-40, -2.1328e-40,  1.0525e-39,
#          4.9238e-39, -4.2743e-40,  3.5496e-40,  9.4631e-41, -2.5523e-40,
#         -4.8543e-05,  5.8069e-40, -5.8360e-01,  8.0255e-41, -1.7495e-40,
#         -3.3701e-40,  2.0974e-40,  9.4962e-41, -4.7280e-40, -2.7966e-40,
#         -2.5886e-40, -3.4947e-41, -3.9978e-40, -4.8027e-39, -4.8459e-40,
#          3.3946e-40, -2.0974e-10,  4.7196e-39,  2.5760e-40, -3.1238e-40,
#         -2.1328e-01, -2.4276e-37, -5.8895e-40,  3.0195e-40, -3.2996e-41,
#          9.7490e-41,  3.9775e-40, -2.2899e-08, -2.1579e-40, -3.4650e-40,
#          6.0799e-40, -3.3682e-40, -2.7548e-40,  3.6968e-37,  1.8398e-40,
#         -7.2757e-41, -3.1750e-40,  2.9614e-40, -2.5501e-40,  1.9318e-40,
#         -6.3448e-01, -5.3901e-40,  2.3352e-40, -6.6353e-01, -4.3315e-40,
#          2.4834e-40, -1.0105e-40,  6.5254e-40,  2.8327e-40, -2.0435e-24,
#         -4.9330e-01, -1.2737e-40, -1.9981e-04, -6.7808e-40, -4.3904e-05,
#          4.1180e-40,  2.0444e-40,  1.0106e-34, -6.6627e-02, -4.7412e-01,
#         -5.9786e-40, -2.0556e-40, -1.7466e-12, -3.4142e-40, -4.2997e-01,
#         -5.7803e-40,  1.9189e-37, -8.0131e-35, -7.8611e-41, -4.9058e-40,
#         -2.5909e-40,  2.7948e-40,  6.0955e-40,  4.7014e-40,  4.2558e-40,
#          1.5036e-40,  4.3333e-40, -8.9130e-41, -5.9222e-19, -3.4418e-40,
#          5.0861e-40,  3.1827e-40,  2.6926e-40,  3.8691e-40, -6.4635e-40,
#         -1.6505e-35,  2.1664e-40,  5.6751e-40, -3.9807e-05, -1.5288e-07,
#         -2.7088e-04,  3.8820e-40,  5.6346e-40, -6.2732e-35, -1.5128e-40,
#         -3.3367e-40, -4.3540e-40, -4.9961e-01,  3.7849e-42,  2.6494e-41,
#          2.1156e-40, -6.7969e-40,  1.5888e-40, -1.9204e-40, -6.6839e-01,
#          2.2657e-40, -1.7213e-04, -4.4645e-40,  5.3574e-41, -1.1176e-39,
#         -4.6732e-40,  4.1503e-40, -6.0140e-40, -9.2061e-36,  4.2578e-40,
#         -3.3537e-40,  5.2295e-40, -1.0759e-40,  8.5324e-41, -6.5087e-01,
#          4.4518e-40, -1.1359e-05,  4.5475e-40, -2.2382e-20,  1.8040e-40,
#          1.0393e-40, -1.3002e-40,  4.9648e-40, -4.5900e-40,  2.9621e-40,
#          3.1621e-24,  5.3065e-40, -1.5758e-40, -2.6446e-40,  1.8552e-40,
#         -4.4720e-41,  6.6536e-40, -2.8774e-40,  3.5793e-40, -4.7834e-40,
#         -2.5349e-04, -1.6897e-40, -1.0398e-03, -4.7129e-28, -6.5666e-41,
#          5.0475e-40, -6.3879e-40, -3.8556e-01,  1.1140e-40,  1.7917e-40,
#         -1.4977e-40,  2.0721e-40, -1.4248e-40,  6.7592e-41,  9.0832e-41,
#         -3.0646e-40,  1.1219e-40, -6.3010e-40,  2.7309e-41, -5.5122e-01,
#          8.9937e-41,  5.1512e-42, -2.6881e-40,  1.6389e-40,  3.2323e-40,
#          3.3499e-41,  1.8517e-40,  3.6780e-40,  5.0368e-40,  5.8498e-40,
#         -3.8240e-40,  1.9157e-35, -2.1732e-40,  1.9962e-40,  3.9705e-40,
#          2.4140e-40,  3.8062e-40, -5.5776e-01,  4.1139e-40, -5.9642e-01,
#         -7.4958e-40, -4.8976e-40,  3.3049e-40, -4.0875e-40, -1.2449e-41,
#          1.4174e-40,  4.3764e-40,  6.1486e-19, -2.0351e-40, -5.4709e-40,
#         -2.0487e-40,  2.6343e-40, -6.7692e-37, -2.6913e-04, -4.2270e-40,
#         -4.1675e-40,  1.3325e-35,  2.8610e-40, -5.5293e-40, -4.1683e-41,
#          1.0852e-40, -9.4211e-41, -4.1906e-40, -4.8187e-01,  5.0749e-40,
#         -1.0934e-41,  5.3214e-40,  3.5746e-41,  1.6778e-40, -9.8758e-41,
#         -4.2375e-41, -5.6063e-01,  2.6313e-40, -4.0938e-40, -2.7250e-01,
#         -9.8253e-41, -3.1697e-01, -4.2254e-40, -3.7974e-40, -3.4820e-40,
#          3.0477e-40,  9.3502e-41, -3.5871e-35, -4.7344e-40, -7.0673e-01,
#         -6.0056e-01,  1.7742e-40, -2.6470e-40, -5.3975e-40, -6.4451e-01,
#         -1.2889e-40, -5.8822e-40, -3.3573e-37, -3.2416e-40,  5.5145e-40,
#         -6.5713e-06,  4.4670e-40,  8.1862e-41, -1.6924e-40, -7.7489e-41,
#         -6.9268e-41, -7.7289e-34, -2.4210e-40, -1.7942e-40, -6.1916e-01,
#         -1.6372e-40, -2.8821e-40,  1.2650e-40,  2.1203e-40,  1.3266e-41,
#         -4.5786e-40, -6.1439e-01,  3.5589e-40, -5.8516e-01,  1.3136e-40,
#         -4.2449e-40, -1.6753e-40,  4.5992e-40, -2.3407e-38, -1.0300e-40,
#         -1.9110e-06, -1.4082e-40,  2.7976e-40,  1.7842e-40, -3.0319e-40,
#         -2.1995e-40, -1.1945e-01,  2.9142e-40, -4.8304e-40, -1.5087e-40,
#          6.4055e-40,  4.9081e-40,  4.4781e-40, -2.0209e-40, -4.5414e-01,
#         -8.3307e-42, -1.5048e-39, -5.8519e-01,  1.2764e-40,  2.9539e-40,
#          4.8316e-40, -6.0302e-40, -1.8023e-40,  3.4495e-40,  9.0179e-41,
#         -1.6615e-40, -4.0543e-40, -1.6267e-01,  3.5134e-40, -1.1673e-37,
#         -7.9531e-41,  1.3967e-40,  5.4046e-40, -4.8969e-01, -1.8463e-07,
#         -8.5340e-41,  1.9895e-40, -6.6462e-41, -2.1176e-40, -6.6699e-41,
#         -6.5186e-01, -1.9986e-40, -2.6480e-41, -9.5456e-05, -5.6365e-40,
#         -2.7175e-40, -4.1139e-40, -5.9997e-01, -3.8411e-39,  3.4427e-37,
#         -1.8421e-06,  9.5510e-41,  4.2010e-40, -5.2648e-41, -2.5852e-40,
#          3.0841e-40, -5.0606e-40, -5.5500e-01, -3.9073e-04, -2.9367e-40,
#         -2.4421e-40, -6.0281e-40, -3.0872e-40, -2.2311e-40,  6.1995e-41,
#         -1.9617e-35, -4.5160e-41,  4.5889e-40,  3.9697e-40, -2.8253e-40,
#          3.8411e-37, -3.5419e-41, -4.4012e-40,  3.0982e-40,  5.3330e-40,
#         -4.3427e-40, -4.7743e-01,  3.3035e-40, -2.5740e-40,  5.2311e-40,
#          3.2591e-40, -4.5488e-40,  9.5384e-41,  1.2562e-38, -1.2616e-41,
#         -6.1237e-40, -1.3249e-40]), 'bn1.running_mean': tensor([-1.7070e-31, -3.8668e-32, -5.9462e-01,  4.7011e-18, -3.6678e-01,
#          4.4001e-36,  2.4772e-31, -5.1403e-32,  1.1982e-33,  2.7861e-31,
#          3.6648e-29, -9.0981e-30, -2.5551e-35,  9.2353e-30,  3.7650e-34,
#          6.4306e-31, -7.5034e-34,  8.7850e-01, -1.5523e-06,  3.0908e-32,
#         -2.6326e-34,  4.9638e-31,  2.0329e-31, -1.8312e-31,  6.7313e-31,
#          6.7510e-05, -5.8183e-32,  8.9843e-35, -7.9531e-31,  8.0462e-34,
#         -1.0845e-29, -4.5175e-31,  8.7470e-31, -6.9717e-32,  4.4007e-30,
#         -6.3078e-01,  3.1949e-29, -9.8812e-34,  1.4856e-32, -2.4147e-02,
#         -5.6356e-01,  6.3867e-31,  2.4453e-22, -4.2288e-01,  6.5933e-30,
#         -6.0610e-34,  1.3247e-01, -7.4614e-32, -4.9681e-32, -2.7415e-31,
#         -1.7157e-31, -1.5747e-28, -7.6689e-01, -2.7290e-32, -2.6030e-30,
#          3.1803e-01,  2.0243e-29, -8.8422e-32, -2.3992e-01,  2.7643e-33,
#          7.0519e-31, -4.3859e-02,  3.0666e-32, -1.7800e-32, -5.4384e-32,
#         -2.0832e-01, -5.7920e-01, -1.8152e-24, -1.2626e+00,  4.9159e-33,
#          1.1061e-29, -1.4019e-33,  2.9184e-31, -4.9614e-32, -9.2357e-32,
#         -2.2208e-30, -2.0472e-31, -6.2616e-31,  2.7325e-31,  1.9417e-01,
#          2.2348e-31, -8.1496e-32, -2.3970e-01,  2.8582e-33,  9.6110e-35,
#         -8.8345e-01,  1.1453e-31, -1.1599e-33, -2.9360e-31, -9.7639e-01,
#         -1.7478e-33,  9.3369e-03, -1.0540e-30, -1.7891e-30,  6.1444e-32,
#         -6.5971e-32, -7.4510e-01, -2.3918e-35,  5.3981e-02,  1.0929e-35,
#         -9.9656e-31, -2.8550e-31, -4.6863e-31,  1.7933e-31,  6.0873e-03,
#          5.2953e-33, -1.9379e-31,  5.4581e-33, -4.0665e-32,  1.3234e-32,
#          3.8804e-31, -6.3577e-35,  3.5314e+00, -6.9704e-31, -3.3948e-29,
#          5.0492e-33,  5.6037e-31,  2.5528e-34, -2.2941e-23, -3.2896e-31,
#          2.8991e-29,  5.1812e-33,  2.8565e-01, -8.0459e-01,  5.7968e-31,
#         -4.5098e-31, -2.7317e-32,  1.1107e+00,  4.6022e-05, -1.5174e-01,
#         -2.9144e-31, -5.1586e-31, -5.9194e-29,  1.6700e-29,  5.4244e-31,
#          1.9997e-32, -1.6423e-15, -8.1921e-32, -4.1806e-31, -9.4266e-33,
#          1.1081e-33,  5.9701e-31,  1.4775e-30, -1.0089e-31,  2.4672e+00,
#         -4.7840e-32,  5.4624e-01,  6.8984e-33, -1.1309e-02,  4.9473e-29,
#          2.5681e-02,  7.5387e-29,  6.8443e-32,  1.7389e-03, -3.2224e-33,
#          6.0951e-32, -6.0819e-32, -2.8387e-32,  7.8704e-32,  1.8640e-34,
#         -2.1217e-29,  8.1660e-30,  6.9673e-33,  2.2026e-32, -1.1504e-31,
#          6.5919e-03, -3.0791e-32,  7.1304e-01,  2.5552e-31,  3.3026e-31,
#          1.0718e-34,  6.9766e-33, -1.4602e-30,  6.2294e-32, -4.8397e-31,
#          6.4089e-31,  7.1981e-31, -6.6306e-31,  8.8836e-31, -3.4222e-30,
#         -4.3001e-32, -3.1210e-07, -7.4971e-31, -9.1240e-30,  9.0300e-32,
#         -1.1922e-01, -4.6212e-34, -2.5187e-31, -6.0077e-31,  2.1595e-34,
#          1.8055e-31,  2.0926e-30, -5.1383e-05, -7.3269e-33, -4.0444e-31,
#         -6.7775e-33, -9.5821e-33, -7.7578e-30,  3.3938e-33, -6.0140e-31,
#          4.0047e-30,  1.7117e-31, -1.8593e-33, -1.0712e-31, -2.0515e-33,
#         -2.5810e-01, -9.0656e-31, -1.2207e-30, -5.1334e-02,  3.7691e-33,
#         -7.0909e-33,  3.6788e-32,  1.4016e-29,  1.2232e-32, -2.4571e-21,
#          1.7438e-01,  1.3685e-31, -1.8320e-02,  2.2917e-31, -1.3018e-03,
#          7.8911e-32,  5.4382e-30,  4.1569e-34, -7.2940e+00,  9.2532e-01,
#         -1.1046e-30,  2.9404e-34,  3.9881e-07, -5.4092e-32, -1.0484e+00,
#         -4.4753e-32, -1.9587e-32, -4.6174e-34,  2.0845e-34,  1.3124e-31,
#          4.8376e-31,  1.1714e-30, -4.4516e-33,  3.2938e-32,  6.3126e-31,
#         -7.5493e-34, -8.2120e-32, -1.7766e-34,  8.7305e-14,  7.8936e-35,
#         -1.1410e-32, -1.3257e-32, -1.5383e-30,  1.3596e-38,  4.7049e-36,
#         -2.8535e-33,  7.3745e-32, -1.4590e-32, -1.0001e-05, -1.0195e-05,
#          6.5897e-06,  5.8969e-31,  1.4445e-31, -6.1616e-33,  9.9875e-29,
#         -1.1710e-31,  5.7447e-32, -5.5236e+00, -6.5165e-32, -5.5882e-30,
#         -7.9399e-34, -1.0820e-31,  5.1531e-33, -1.2077e-30, -2.5090e-01,
#         -7.7245e-31,  1.3310e-02,  1.1839e-28, -2.6783e-31,  3.1355e-29,
#          1.1283e-32,  5.8588e-33, -6.6124e-32,  3.8198e-32, -1.5920e-31,
#          7.6618e-31,  6.6502e-33,  2.6247e-32, -2.2559e-33, -4.9652e-01,
#         -5.5283e-31,  1.4289e-02, -3.6937e-32,  9.4116e-22,  1.1146e-32,
#          1.6908e-28,  4.6141e-32, -1.7962e-31,  7.4728e-34,  7.2368e-32,
#          2.1447e-20, -8.3325e-34,  1.9400e-32,  1.5311e-32,  2.4267e-29,
#          4.1707e-31,  5.9131e-32, -6.7930e-32, -4.5508e-34, -1.6692e-30,
#          6.7883e-03, -1.6400e-32, -1.7241e-02, -6.2166e-25, -8.5940e-31,
#          4.4690e-32,  5.7740e-32, -1.9473e-01,  2.8082e-29, -6.5691e-33,
#         -1.6555e-31, -1.6589e-31, -5.5425e-33,  1.0304e-31, -1.0970e-33,
#          3.4312e-34,  3.6051e-33, -3.7608e-31,  7.9247e-32, -1.5585e-01,
#         -1.2627e-33,  4.8985e-31,  1.0712e-29, -4.4225e-32, -1.7323e-34,
#          3.0808e-29,  1.1361e-31, -9.9795e-31,  1.2308e-31,  2.5534e-29,
#          2.9486e-31,  1.0202e-29,  1.9041e-29, -1.4159e-29,  1.6257e-30,
#         -2.0468e-32, -8.9000e-31,  8.8400e-01, -6.3319e-33,  1.0239e+00,
#          3.8821e-34, -1.5123e-32, -2.2032e-30,  7.8562e-32, -1.8639e-31,
#         -6.7999e-31, -9.6427e-31, -1.4710e-13, -6.4514e-31, -2.3321e-31,
#         -1.0203e-31, -5.3626e-32, -1.8939e-32, -2.9555e-02,  2.1263e-33,
#          2.0248e-33, -7.5668e-30, -3.7748e-31,  5.4991e-29, -3.5307e-32,
#          2.6704e-33,  1.3293e-31, -3.1461e-31, -8.1497e-02,  9.1022e-31,
#         -9.9899e-31, -4.4975e-36,  1.7903e-31, -1.8196e-34, -8.2291e-32,
#         -1.0535e-31, -4.4303e-01,  5.1610e-32,  6.4497e-37,  2.6302e+00,
#         -4.3425e-33,  2.2503e-02, -1.6696e-32, -1.2082e-31, -3.6845e-35,
#         -7.1840e-31, -8.9952e-32,  8.2501e-31, -1.6819e-30, -5.4719e-01,
#         -2.6342e-02, -2.0483e-31,  1.0397e-30, -1.4198e-33, -5.1260e-01,
#          3.3051e-31, -1.5684e-30,  1.7322e-35, -3.5138e-31, -3.1797e-32,
#         -1.4063e-04, -1.7545e-32,  4.4084e-30,  4.2448e-32,  7.2555e-32,
#          5.4089e-32,  5.1950e-34,  1.2863e-33, -2.3788e-31,  1.0031e-01,
#          2.2764e-33, -2.2767e-34, -3.2459e-32, -9.4582e-35,  4.3502e-32,
#          5.1384e-32,  4.2792e-01,  2.5373e-32, -7.1196e-01, -6.9024e-33,
#          4.0771e-34,  1.5328e-30,  6.9400e-34, -2.9120e-31,  1.1437e-28,
#         -1.0956e-04,  4.1385e-32, -2.8309e-29,  2.0724e-31,  1.1315e-30,
#          2.8110e-31,  1.2444e+00, -8.1297e-31, -4.8282e-32, -1.8367e-31,
#          4.9505e-31,  3.3419e-34,  1.0918e-30,  6.8763e-30, -7.6780e-01,
#          6.9253e-32, -2.6864e-31,  5.6766e-02,  1.4577e-31, -1.5439e-33,
#         -2.6684e-31, -5.8098e-29, -9.0799e-31,  5.1205e-31, -1.9393e-33,
#          4.4956e-32,  1.3792e-29,  6.0190e+00, -2.7852e-31,  2.8835e-32,
#          5.0575e-31, -5.7228e-32, -4.1288e-32,  9.2283e-01, -1.2380e-06,
#         -3.0821e-33,  1.5245e-29,  4.5539e-32,  5.7469e-33,  6.5472e-30,
#          6.4378e-01,  1.1310e-31, -3.7444e-31, -2.9071e-03, -2.6766e-33,
#         -1.6232e-28,  4.2941e-31, -2.4498e-01,  1.7849e-35, -6.0990e-35,
#         -1.6327e-06, -2.5497e-32, -2.5824e-30, -1.6633e-31,  4.1303e-29,
#         -2.0222e-32, -1.3509e-30, -6.5950e-01,  3.5595e-02,  1.4893e-31,
#          2.2751e-31, -8.4002e-31, -1.6213e-36,  5.5928e-35,  2.5477e-32,
#          1.8460e-33, -2.2095e-31, -7.3087e-31, -1.2796e-30, -2.1455e-31,
#          2.1383e-34, -4.8629e-34,  2.8378e-34, -7.1537e-34,  9.1641e-32,
#          6.8820e-31,  1.2393e-01, -9.6116e-32, -1.6375e-31, -2.9834e-29,
#         -2.1502e-34,  4.3198e-32, -2.3365e-29,  5.7559e-34, -2.3474e-31,
#          9.6956e-33, -1.3254e-29]), 'bn1.running_var': tensor([5.6052e-45, 5.6052e-45, 4.7337e-01, 2.0907e-35, 1.0166e+00, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.8182e-01,
#         6.7516e-11, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 4.0599e-08, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 7.2673e-01,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 3.7586e-04, 6.6040e-01, 5.6052e-45,
#         7.0065e-44, 8.9830e-01, 5.6052e-45, 5.6052e-45, 7.0966e-01, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 8.2275e-01, 5.6052e-45,
#         5.6052e-45, 4.4862e-01, 5.6052e-45, 5.6052e-45, 2.8442e-01, 5.6052e-45,
#         5.6052e-45, 5.6712e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45, 6.6398e-01,
#         1.0933e+00, 5.6052e-45, 1.4867e+00, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 1.0526e+00, 5.6052e-45, 5.6052e-45, 8.6837e-01, 5.6052e-45,
#         5.6052e-45, 1.0643e+00, 5.6052e-45, 5.6052e-45, 5.6052e-45, 8.1564e-01,
#         5.6052e-45, 1.0145e+00, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         9.5432e-01, 5.6052e-45, 4.5716e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 3.8616e-05, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 2.4628e+00, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 1.9618e-44, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 9.2035e-01, 4.5793e-01, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.3398e-01, 5.3387e-10, 3.7957e-01, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 3.3644e-30, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         9.8281e-01, 5.6052e-45, 1.4289e+00, 5.6052e-45, 1.0524e-04, 5.6052e-45,
#         2.1451e-03, 5.6052e-45, 5.6052e-45, 1.7589e-06, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 1.0803e-04, 5.6052e-45, 1.5864e+00,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 3.0592e-13, 5.6052e-45, 5.6052e-45, 5.6052e-45, 9.0278e-01,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         2.7868e-09, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.1888e-01, 5.6052e-45, 5.6052e-45, 6.2710e-01, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 2.1991e-40, 1.1414e+00,
#         5.6052e-45, 1.1189e-04, 5.6052e-45, 1.0706e-06, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.8661e+00, 8.3471e-01, 5.6052e-45, 5.6052e-45, 1.4365e-13,
#         5.6052e-45, 7.2315e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 1.8779e-26, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 1.7916e-10, 6.2370e-11, 3.1195e-11, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 2.7624e+00, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 7.1201e-01,
#         5.6052e-45, 1.8468e-04, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.8162e-01, 5.6052e-45, 1.3091e-04, 5.6052e-45,
#         5.0023e-39, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 1.9910e-39, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 2.1739e-04,
#         5.6052e-45, 1.9207e-04, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         7.5839e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.0070e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         6.7718e-01, 5.6052e-45, 5.7245e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 2.1938e-26, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.8366e-04, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 4.2049e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 9.8159e-01, 5.6052e-45,
#         5.6052e-45, 2.7843e+00, 5.6052e-45, 1.3696e+00, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 7.5558e-01,
#         1.0910e+00, 5.6052e-45, 5.6052e-45, 5.6052e-45, 6.6997e-01, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 7.5003e-09, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 4.8463e-01, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.1900e-01, 5.6052e-45, 9.5840e-01, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 1.7707e-07,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 1.6786e+00,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 9.5099e-01, 5.6052e-45, 5.6052e-45, 5.0669e-01, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.2189e+00, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 6.1216e-01, 1.4684e-12, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.7273e-01, 5.6052e-45, 5.6052e-45,
#         1.0856e-05, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.2056e-01, 5.6052e-45,
#         5.6052e-45, 3.9322e-11, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 8.1633e-01, 3.0805e-04, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 1.2644e+00, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45, 5.6052e-45,
#         5.6052e-45, 5.6052e-45]), 'bn1.num_batches_tracked': tensor(35000), 'fc2.weight': tensor([[ 2.9586e-41,  4.3515e-40, -1.8692e-02,  ..., -4.2989e-40,
#           9.6290e-41,  4.9808e-40],
#         [-1.4995e-40,  1.6171e-40, -6.1377e-02,  ...,  4.2617e-40,
#           2.1619e-40, -1.2902e-40],
#         [ 2.4041e-41, -1.3265e-40, -3.6866e-02,  ...,  2.5492e-40,
#           5.6133e-40, -2.3020e-40],
#         ...,
#         [ 2.7756e-40,  5.2494e-41,  1.1659e-01,  ...,  7.3703e-41,
#          -1.6907e-40, -5.1146e-40],
#         [ 2.8941e-40,  4.4028e-40, -3.8873e-02,  ...,  5.2753e-41,
#          -5.7811e-41, -6.0465e-40],
#         [ 5.7379e-41, -2.1112e-40,  1.2760e-02,  ...,  2.9638e-40,
#          -2.3144e-40, -3.7245e-40]]), 'fc2.bias': tensor([ 1.8347e-05,  1.6483e-06, -4.0905e-06,  6.3760e-06,  2.7334e-06,
#         -2.7496e-05,  1.9655e-06,  1.1334e-05,  4.6671e-05, -5.3882e-06,
#         -6.5229e-06, -1.3191e-12, -1.0464e-05, -9.5956e-06, -4.1086e-07,
#          3.0006e-06,  2.3388e-05,  1.0168e-05, -7.5881e-06,  2.0632e-12,
#         -2.1570e-05,  2.8274e-06, -7.3596e-06,  2.4020e-05,  1.1195e-05,
#         -3.7727e-06, -2.5672e-05,  2.6935e-05,  2.1062e-05,  4.5001e-05,
#          1.1075e-06,  4.8501e-06,  7.2411e-07, -1.9354e-07, -1.3538e-05,
#          2.0725e-05, -1.5104e-05,  9.6467e-06, -2.0003e-05,  5.8309e-06,
#          1.4069e-05, -2.2687e-06,  2.0833e-05,  4.6362e-05, -1.3454e-05,
#         -1.4436e-05, -2.7636e-06,  3.8844e-07, -6.4759e-06, -2.9730e-05,
#          1.8423e-05, -4.5940e-06,  4.7600e-06, -1.6946e-05, -1.6639e-06,
#         -1.9954e-05, -2.0274e-06,  3.0874e-06, -2.7565e-06,  1.5466e-05,
#          1.5554e-06,  2.5633e-05, -2.9705e-06, -3.2011e-05,  1.2837e-05,
#          4.4632e-06,  2.1050e-05,  2.3549e-06, -6.5793e-06, -6.7580e-06,
#         -2.4189e-06, -6.0453e-07,  7.4857e-06,  4.6740e-05,  3.8112e-05,
#          6.8824e-06,  3.6038e-06, -1.3875e-06,  2.8400e-06,  2.5034e-06,
#          6.7817e-06,  2.0237e-07,  8.2784e-08, -3.6859e-06,  1.0373e-05,
#          2.8488e-07,  1.3304e-05, -1.6481e-05, -3.3789e-05, -6.4031e-06,
#         -1.6429e-05,  4.6662e-06, -6.0672e-05,  6.4466e-06,  2.8475e-07,
#         -1.4184e-05,  3.8328e-05, -1.4422e-06, -6.3808e-06,  2.0672e-06,
#          1.1121e-05, -2.7376e-06,  3.0644e-08,  9.2483e-06,  1.0089e-05,
#          6.1401e-05, -5.3324e-06, -4.2812e-07,  1.2849e-05, -7.7037e-06,
#         -1.0473e-05,  1.9526e-05, -1.8652e-05, -2.5124e-05, -7.3503e-06,
#         -1.0630e-05,  1.4362e-05, -1.9350e-10,  5.6131e-06, -8.1696e-06,
#         -5.4714e-05,  6.5742e-06, -7.8773e-06,  1.3336e-05, -3.5627e-05,
#         -5.1037e-08, -3.8199e-07,  1.6497e-05,  5.8171e-06,  4.0088e-06,
#         -1.8234e-09,  4.0920e-05,  2.0044e-05, -7.4607e-06, -2.1474e-07,
#          2.1834e-05, -5.1726e-06, -1.2459e-09, -1.1549e-06, -1.2604e-05,
#         -1.7812e-05,  5.3926e-05,  1.6135e-05,  1.7577e-06,  5.7821e-06,
#          1.0032e-05,  8.4915e-06,  4.1610e-07, -1.7778e-07,  8.7746e-06,
#          5.8613e-05, -3.6925e-05,  1.5110e-06,  1.4001e-05,  1.3912e-05,
#          8.0193e-05, -1.5747e-05, -1.6755e-05, -1.8595e-05,  3.9626e-06,
#         -1.0082e-05,  8.8198e-06, -2.6100e-05,  1.1129e-05, -1.0287e-05,
#          1.7508e-06,  1.1689e-06, -1.2455e-05,  2.0439e-06,  7.4682e-06,
#         -2.9512e-05, -5.8742e-06,  4.4190e-06, -1.7483e-10, -1.3093e-06,
#          1.5147e-05, -1.0287e-05, -1.0527e-05,  1.7146e-13, -4.6361e-05,
#         -1.4098e-05,  1.2859e-05, -3.6334e-06, -6.0139e-09,  8.1499e-06,
#         -6.2489e-07,  5.4120e-15, -2.8123e-05, -2.1686e-05,  1.0284e-05,
#         -1.4223e-05,  2.4915e-05,  3.2149e-09, -4.8141e-09,  5.4454e-05,
#          9.2949e-07, -5.4319e-06,  1.7297e-05, -1.0743e-05, -6.4064e-06,
#          1.8378e-05,  4.0630e-06,  8.5070e-06, -5.0455e-06,  1.0459e-05,
#          3.7549e-05, -1.5603e-06, -8.4144e-06,  5.8103e-06,  2.0979e-05,
#          1.4659e-05,  8.0839e-10,  5.3004e-06,  2.0747e-05,  1.3149e-05,
#          3.4727e-05,  1.6367e-05,  8.4502e-06, -4.6204e-06,  9.3238e-06,
#         -1.7023e-05,  1.2425e-05, -1.9532e-05, -2.8762e-06,  9.7668e-06,
#          1.2657e-10, -1.1584e-05,  1.2020e-05, -4.5466e-06, -2.5435e-05,
#         -2.6696e-06, -3.1457e-05, -6.6306e-09,  8.7688e-09, -1.4187e-05,
#          2.5509e-07, -1.3000e-05, -4.1885e-05, -5.5478e-06,  6.6459e-06,
#          1.0046e-05,  1.0656e-08, -1.2882e-06,  2.2397e-05, -5.7648e-06,
#          8.6272e-06, -3.2658e-08,  2.2847e-06, -9.3199e-06, -1.7816e-05,
#          3.0151e-06,  5.7742e-06,  5.4188e-06, -1.0776e-05, -1.3476e-05,
#         -4.6749e-06]), 'bn2.weight': tensor([ 1.7861e-01,  2.8754e-01,  2.4267e-01,  1.1222e-01,  8.4886e-02,
# ...
#          -1.1502e-01, -2.8216e-07, -3.6104e-02, -1.4833e-01,  2.9085e-01,
#          -9.8246e-02,  1.4860e-01, -2.5090e-01,  1.7230e-10,  5.4200e-02,
#          -2.6729e-01, -1.7116e-01, -8.7753e-02, -8.8021e-04,  3.0650e-02,
#          -1.1536e-03,  8.8380e-03,  4.3591e-02, -1.1258e-01,  2.9365e-02,
#           1.3141e-01, -2.6295e-01,  1.8740e-02, -1.7234e-01,  3.4763e-01,
#          -1.8341e-01, -4.4641e-02, -8.5442e-03, -1.9978e-01,  2.5249e-01,
#          -2.5726e-01,  3.7238e-01,  1.5563e-01, -1.0458e-01, -1.4786e-01,
#          -1.5383e-01, -1.7040e-01,  2.3734e-02,  4.0564e-01],
#         [ 1.5764e-01, -1.7986e-02,  3.3510e-01,  3.7222e-03,  1.8703e-01,
#           8.0864e-02,  1.4966e-01,  1.7348e-02,  1.0997e-01, -4.5111e-02,
#          -1.7747e-01,  3.0750e-01, -3.3914e-02, -8.7912e-02, -1.9921e-01,
#          -2.3761e-01,  1.5853e-01,  3.2183e-01, -2.6598e-01, -2.4413e-01,
#           1.1113e-01, -1.8301e-01, -1.7727e-01,  1.1435e-02,  3.5319e-02,
#          -4.0723e-02,  2.8363e-06,  2.8491e-01, -1.8343e-01, -2.9953e-02,
#           3.2354e-01, -2.5467e-01,  1.1964e-01, -2.7269e-08, -2.7239e-02,
#          -4.1225e-02,  2.3901e-01,  1.5601e-01,  1.8145e-03,  1.6931e-02,
#          -1.8052e-03,  3.6012e-02, -2.0061e-02,  2.5370e-01, -1.2229e-01,
#          -8.2798e-02,  4.6984e-02, -1.3221e-01, -1.9841e-01, -1.1375e-01,
#           7.2104e-02,  2.4354e-01, -1.8708e-01, -5.5119e-02, -2.4041e-02,
#          -1.2311e-01,  2.0301e-01, -5.3755e-03, -1.3242e-01, -3.3751e-02,
#          -3.1348e-01, -1.9458e-01, -4.2242e-02, -2.1674e-01],
#         [-1.3822e-01, -6.3776e-02, -2.5157e-02, -1.5396e-02, -6.8896e-03,
#           1.0694e-01, -7.4791e-02,  5.4243e-02, -6.0599e-02, -1.7981e-01,
#           3.0101e-01, -1.7266e-01, -2.4478e-01, -1.3924e-05,  1.0097e-02,
#          -1.6024e-01,  1.8225e-01, -2.5230e-02,  2.2253e-01,  2.5768e-01,
#          -5.9808e-02,  1.6125e-02,  1.2223e-01, -6.5476e-03,  4.1871e-02,
#           2.9787e-03,  6.1721e-07, -1.7071e-01,  2.5737e-01,  2.3220e-01,
#          -1.6128e-01, -3.0332e-02, -2.8672e-02, -1.1625e-08, -1.3399e-02,
#          -1.3386e-01,  2.6584e-01, -3.1311e-01,  1.5120e-03, -9.5917e-03,
#           7.2469e-03, -1.5723e-01,  1.8746e-01,  2.9265e-01,  1.5769e-01,
#          -1.5349e-01,  1.2917e-01,  2.1551e-02, -7.2857e-02,  2.2844e-01,
#           3.8666e-01, -6.2887e-02, -3.1787e-01, -1.3163e-01, -2.0254e-01,
#          -5.5914e-02, -2.4158e-01, -1.6060e-01, -9.5092e-02, -4.1641e-02,
#           1.9612e-01, -1.1860e-01,  3.8220e-02, -1.2305e-01],
#         [ 2.0699e-01,  9.3255e-02, -5.8777e-02,  1.5499e-02,  2.4616e-01,
#          -6.0277e-02, -1.9471e-01, -1.2125e-01, -2.4288e-01, -1.7052e-01,
#           2.8888e-01,  9.0409e-02,  2.3550e-01,  2.4399e-02,  6.4377e-03,
#          -1.2595e-01,  5.8263e-02,  5.8152e-02,  1.9356e-01,  1.0048e-01,
#          -3.0681e-02, -9.8554e-02,  1.4181e-01, -1.8661e-02,  1.7534e-03,
#           8.8090e-02, -8.8822e-07,  6.4182e-02,  5.0903e-02,  2.1478e-01,
#           9.1802e-04, -9.5089e-02, -1.9804e-01, -1.9446e-08, -5.5304e-03,
#          -1.4912e-01, -3.4106e-01, -1.0203e-01, -9.4896e-04,  2.1358e-02,
#          -1.7847e-05,  3.9848e-01, -1.7829e-01,  2.7318e-01, -5.0093e-02,
#          -9.9067e-03, -5.0647e-02,  1.8016e-01,  2.6139e-01, -1.8781e-02,
#           3.5467e-01, -2.5066e-01, -2.7001e-01,  3.3586e-02, -1.1105e-01,
#           9.8553e-02, -2.1525e-01, -6.0002e-02,  4.0467e-02,  8.2849e-02,
#           1.3330e-01,  6.4952e-02,  9.6713e-02, -5.1587e-02],
#         [-7.0986e-02,  4.9842e-03,  1.8321e-01,  2.6692e-02,  2.6861e-02,
#          -1.9423e-01, -2.1886e-01,  2.0534e-01, -7.3522e-02, -1.5241e-01,
#          -1.1483e-01,  4.8617e-02, -9.9654e-03, -9.4351e-02, -1.0604e-01,
#          -1.4362e-01, -1.3675e-01, -4.2533e-02,  2.4002e-01, -2.0352e-01,
#          -5.8232e-02,  9.7467e-03,  1.9019e-01,  1.8088e-02, -2.4969e-02,
#          -5.9011e-02,  3.2988e-07,  2.6603e-01, -8.1465e-02, -3.8679e-01,
#          -1.6338e-01, -4.9212e-02, -1.4918e-01, -7.3685e-09,  9.6592e-03,
#          -4.3758e-02,  1.6879e-01,  1.6201e-01,  1.6448e-03,  5.6609e-03,
#          -6.1648e-04, -1.0717e-01,  2.5070e-01, -2.4962e-01,  2.2491e-01,
#          -3.1633e-01, -1.0012e-02,  1.8479e-01,  2.7721e-01,  6.4297e-02,
#           2.2872e-01, -2.8745e-01,  3.5482e-01,  6.9888e-02, -1.1883e-01,
#           5.8490e-02, -5.7478e-02,  5.5477e-02,  2.9110e-01,  2.1734e-01,
#           1.8279e-01, -1.6010e-01,  3.6365e-02, -4.8490e-02],
#         [-1.2337e-01,  1.4995e-01, -2.6671e-01, -5.6448e-03, -1.3114e-02,
#          -2.5992e-01, -4.1024e-02, -2.4817e-01,  5.9968e-02,  1.4626e-01,
#           3.7030e-01,  3.6672e-01,  1.2318e-01, -5.2389e-02, -9.3833e-02,
#          -2.1058e-01, -1.4991e-01,  7.9673e-02, -1.4161e-01, -5.4209e-02,
#          -1.3342e-03, -1.4294e-02, -1.6731e-01, -7.3785e-02,  6.2228e-02,
#          -1.0458e-01,  2.1282e-07, -1.3846e-01, -1.6306e-01, -2.6478e-01,
#           5.1873e-02,  1.4576e-01, -1.9504e-01, -9.3025e-09,  2.3424e-02,
#          -5.0512e-02,  6.8185e-02, -4.6790e-01,  3.4442e-03, -1.6945e-03,
#           1.3625e-03, -2.2229e-01,  1.7700e-01, -2.9162e-01,  1.3134e-01,
#           2.8822e-01, -2.5315e-01,  1.8460e-01, -4.7517e-01,  2.4314e-01,
#           2.1406e-01,  1.4060e-01,  3.4035e-01,  2.3760e-02, -1.3463e-01,
#          -7.7127e-02, -1.7897e-02,  5.7692e-02,  1.9381e-01, -3.0194e-01,
#           1.6779e-01,  2.9521e-01,  4.1715e-02, -6.3794e-02],
#         [ 1.4352e-01,  1.0191e-01, -3.0334e-01, -2.8543e-02, -1.0077e-01,
#          -6.4491e-02, -3.0806e-01, -8.4551e-02, -6.2211e-02,  8.9217e-02,
#          -1.2006e-01, -2.7259e-01, -1.8742e-01, -9.3638e-02,  1.2874e-01,
#           1.5467e-01, -2.7265e-01,  3.8272e-01,  8.3442e-02,  2.0377e-02,
#          -5.4540e-02,  2.2413e-01,  2.3872e-01, -1.2443e-01, -9.5460e-02,
#           1.6139e-01, -4.9420e-07, -1.7843e-03, -4.0002e-01,  1.0090e-01,
#          -5.6214e-02, -1.2843e-02,  2.3504e-01, -8.0784e-09, -3.7215e-02,
#           2.2888e-01,  1.9953e-01, -1.5047e-01,  7.6514e-04, -1.8992e-02,
#          -1.4897e-03, -3.1404e-02, -1.7078e-01,  3.0752e-02,  2.1283e-01,
#           2.4108e-01,  3.6304e-01, -1.5089e-01, -1.4413e-01, -2.8044e-01,
#          -1.6425e-01, -5.4332e-02, -1.0061e-01, -4.5290e-01,  1.9495e-01,
#           3.5069e-01,  8.3637e-02, -1.8643e-01, -1.1487e-01,  2.5107e-01,
#          -1.5943e-01,  2.3740e-01, -1.8421e-02,  1.2329e-01],
#         [ 4.1355e-02, -3.8345e-01, -2.4430e-01, -2.5912e-02,  2.3595e-01,
#           1.2517e-01, -2.2616e-01,  1.7497e-01, -4.6967e-02, -1.2677e-01,
#          -4.9690e-02, -1.1046e-01, -2.0685e-01,  1.2481e-01,  7.3571e-02,
#           2.6903e-01,  3.7931e-01,  3.0577e-02, -8.8924e-02, -3.1093e-02,
#           1.3936e-01, -2.0716e-01,  5.1348e-02,  1.1409e-01, -5.8110e-02,
#          -1.1427e-01,  8.1383e-07, -1.4526e-02, -6.2245e-02, -1.6033e-01,
#           1.8533e-02,  4.5023e-02, -6.1881e-02, -1.2878e-09, -3.3707e-02,
#           3.3155e-01, -1.2104e-01, -5.0219e-02,  1.3873e-03,  4.9179e-02,
#           1.2460e-03, -6.0304e-03,  3.8014e-01, -8.6886e-03, -2.8899e-01,
#           2.6884e-01, -4.0548e-01, -7.0042e-03,  1.4151e-01, -2.3297e-01,
#          -2.3661e-01,  6.3938e-02,  3.4153e-02,  3.5553e-01,  2.3686e-01,
#           2.1116e-01, -2.3970e-01, -2.2106e-01, -1.9567e-01, -1.1783e-01,
#          -1.0589e-01, -1.7792e-01, -3.6595e-02,  3.6564e-01],
#         [ 2.3900e-02,  7.6673e-03, -2.0402e-01,  1.0087e-02, -1.8165e-01,
#           1.3509e-04,  3.0498e-01,  1.3997e-02,  2.7204e-01, -3.8098e-02,
#          -1.4524e-01,  2.3217e-01, -2.5567e-01,  3.3236e-01,  5.3364e-01,
#          -2.8012e-01,  8.3528e-02, -1.9358e-01, -2.2077e-02,  1.3330e-01,
#          -5.4673e-02, -2.0003e-01, -7.9027e-02,  2.6631e-02,  3.6937e-02,
#           3.0472e-01,  7.1353e-06,  1.2295e-01, -6.8496e-02, -6.6596e-02,
#           1.0755e-01, -1.7601e-01,  1.5138e-01,  1.6972e-08,  4.3840e-02,
#          -8.1828e-03, -1.6036e-01,  2.9378e-01, -1.6230e-03,  1.5973e-02,
#           6.0027e-05, -5.3117e-02, -4.9364e-02, -3.8445e-03, -9.8913e-02,
#           2.0420e-01,  1.8038e-01,  2.6858e-01, -1.3046e-01, -1.2566e-01,
#          -2.1204e-01, -2.7853e-01,  2.5672e-01, -5.2234e-02, -9.1270e-02,
#          -1.4657e-01,  2.7741e-01, -1.4805e-01, -5.0219e-02, -9.4603e-02,
#           1.6917e-01, -2.4533e-01, -3.5886e-02, -1.3844e-01],
#         [ 1.2057e-01, -1.2884e-01,  9.1728e-02,  2.9906e-02, -1.3270e-01,
#          -1.8868e-01, -1.7066e-01, -6.6462e-02, -1.7711e-01,  1.3326e-01,
#          -3.2025e-02, -2.7906e-01, -1.0370e-01, -1.0024e-01, -1.3450e-01,
#          -2.1420e-01, -1.3465e-01, -2.6651e-01, -3.0857e-02,  1.5545e-03,
#          -7.5360e-02,  2.5048e-01,  1.9959e-01,  3.4850e-02,  1.3685e-01,
#           2.6093e-01, -1.3431e-07, -2.3930e-01,  4.0631e-01,  1.3310e-01,
#           3.0890e-01,  2.0126e-02,  1.9942e-01,  1.1077e-08,  2.9783e-02,
#           1.7630e-02, -7.6219e-02, -2.1184e-01, -3.2250e-03,  2.4414e-03,
#          -1.4801e-03, -3.4208e-02,  4.9084e-03, -9.2769e-02, -1.5350e-01,
#          -7.5391e-02, -2.6210e-01,  2.8137e-03, -9.2743e-02, -1.4735e-01,
#          -2.7354e-01,  1.3344e-02, -4.5656e-02,  3.2491e-01,  2.6255e-01,
#          -1.7124e-01,  3.0682e-01,  9.7853e-02,  1.6068e-01,  3.8938e-01,
#          -3.0039e-01,  2.1502e-01,  1.0104e-01, -2.1847e-01],
#         [ 7.6384e-03,  1.2372e-02,  1.0294e-01, -1.3512e-02, -2.8576e-01,
#          -2.2488e-01,  4.1578e-02,  9.5492e-03,  5.1199e-03,  6.1035e-03,
#          -3.3838e-01,  1.5048e-01,  1.3405e-01, -2.0643e-02, -2.1725e-01,
#          -8.4781e-02,  9.8614e-02,  3.5578e-02, -2.4089e-01, -2.8272e-01,
#           8.5129e-02, -8.8944e-02, -2.1284e-01,  1.7020e-02,  2.5513e-01,
#          -3.6519e-01,  3.0038e-06,  2.2769e-01,  6.0173e-02,  3.5351e-02,
#          -2.6313e-01,  3.7331e-01,  1.6033e-01,  1.0881e-08, -4.3955e-02,
#           1.0066e-02,  2.5991e-01,  4.4688e-01, -4.2920e-04,  1.8463e-02,
#           2.9734e-04,  1.4486e-01, -1.0493e-01, -1.3886e-01, -1.1139e-01,
#          -1.1455e-01, -1.9734e-01, -4.8666e-02, -5.9118e-02, -1.2324e-01,
#           3.1860e-01,  1.2815e-01, -1.9712e-01, -1.4658e-01, -2.0465e-02,
#          -4.5000e-02,  6.3572e-02,  1.1459e-01,  5.3735e-02,  1.0879e-01,
#           2.7392e-01,  3.9409e-02, -2.6407e-02,  2.0179e-01],
#         [-6.0903e-03,  2.2108e-01, -1.0259e-01, -2.9106e-02, -3.2246e-01,
#           2.3076e-01,  3.3977e-01, -1.1599e-02, -8.5469e-02,  7.9159e-02,
#          -1.5879e-02, -3.6000e-01,  7.0271e-02, -6.0308e-02, -1.2904e-01,
#           3.6261e-01, -2.3476e-01, -1.9034e-01,  2.2722e-01,  1.3509e-02,
#           7.1875e-02,  1.8985e-01, -1.4393e-01,  7.2220e-02,  1.4285e-01,
#           1.7370e-01,  1.2596e-06, -1.3965e-02, -2.6818e-01, -3.5870e-02,
#          -1.1089e-01, -1.0650e-01,  2.8510e-01,  6.0634e-09, -3.1340e-02,
#          -2.1397e-01, -2.9432e-02, -2.7731e-01,  4.9600e-04,  2.4872e-02,
#           3.0761e-03, -1.5261e-02,  8.0576e-02,  2.6589e-02, -2.4514e-01,
#          -2.4981e-01, -3.7397e-02, -4.0470e-03,  2.1232e-01, -6.5149e-02,
#          -5.6159e-02,  3.2212e-01,  3.2961e-02,  2.9367e-01, -2.5092e-01,
#           4.7919e-01, -2.4024e-01,  2.7453e-01, -1.4521e-01, -1.3840e-01,
#          -1.3504e-01,  4.0010e-02, -5.3862e-02, -1.0714e-01],
#         [-8.4465e-02, -2.6731e-01,  1.1992e-01,  3.8602e-02,  2.2630e-01,
#          -2.1881e-01,  4.5695e-01, -1.5776e-01,  8.3742e-02,  2.2344e-01,
#          -4.2154e-02, -2.9555e-01,  3.4267e-01, -9.7536e-02,  1.5833e-01,
#           2.6970e-01, -2.4892e-01, -1.7318e-01, -1.3251e-01, -8.4293e-02,
#           5.0967e-03,  1.4460e-01, -2.9510e-01,  7.7162e-02, -1.1564e-01,
#          -3.1446e-02,  3.7740e-07, -1.2468e-01,  3.2422e-01, -1.5825e-01,
#           1.4893e-02, -3.1016e-02, -1.1921e-01, -6.8237e-09,  4.2074e-02,
#           3.9373e-01, -1.5530e-01, -1.4528e-01,  7.9839e-04, -2.3612e-02,
#           9.1210e-04,  1.1429e-03, -2.2312e-02,  7.2943e-02,  4.0732e-01,
#          -1.5318e-01,  1.2445e-01, -5.2804e-02,  2.7213e-01,  1.4891e-01,
#          -2.8938e-01,  2.0272e-01, -3.1137e-02, -1.8733e-01, -2.6787e-01,
#          -2.1120e-01, -3.2013e-01, -2.0105e-01, -2.9176e-01,  1.4743e-01,
#          -1.8720e-01, -9.0408e-02, -2.3307e-02,  6.2066e-02],
#         [-1.7525e-02,  9.0780e-03,  7.8640e-03,  1.2716e-02, -1.6978e-01,
#           4.0858e-01,  3.9818e-02, -3.8200e-02,  4.9929e-02, -2.0619e-02,
#          -2.4312e-01,  2.4477e-01,  3.3520e-01,  8.4338e-02, -1.8721e-01,
#          -2.8524e-01,  8.9253e-02, -1.3412e-01,  1.2936e-01,  4.3243e-01,
#          -6.2823e-02, -4.6982e-02, -1.3685e-02, -4.6676e-02, -1.0511e-01,
#          -2.0679e-01,  1.7497e-06, -2.8243e-01, -1.2623e-01, -8.6523e-02,
#           9.0082e-02,  6.5683e-02,  6.2561e-02,  2.5871e-10,  9.5601e-02,
#           1.6857e-02, -4.2846e-02,  3.5391e-01, -1.0547e-03, -1.2092e-02,
#          -6.0668e-04, -1.3963e-01, -2.6062e-01,  2.3112e-01, -7.3313e-02,
#           1.0765e-01,  1.1639e-01, -2.0960e-01, -1.0728e-01, -1.3260e-01,
#          -2.0932e-01, -1.7876e-01,  8.9766e-02,  6.7602e-02, -9.5886e-02,
#          -9.1790e-02,  5.0007e-02, -4.3640e-02, -8.5746e-02, -2.4153e-01,
#          -7.1751e-03,  1.5807e-01,  4.2936e-02, -7.8609e-02]]), 'fc5.bias': tensor([-0.0772, -0.0346,  0.0884, -0.0373, -0.0134, -0.0488,  0.0750, -0.0768,
#         -0.0459,  0.0329,  0.1050,  0.0168,  0.0249, -0.0733,  0.1271])})
# Best model saved at ./best_model_mlp.pth
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[39], line 14
#      12 WEIGHT_DECAY = 1e-3
#      13 grad_history = {name:[] for name, _ in deep_model.named_parameters()}
# ---> 14 train_losses, train_acc, val_losses, val_acc = train_model(deep_model, epochs=EPOCHS, learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY, grad_history=grad_history)
#      16 plt.figure(figsize=(15, 5))
#      17 plt.subplot(1, 2, 1)
#
# Cell In[37], line 53, in train_model(model, epochs, learning_rate, weight_decay, grad_history)
#      51 print(best_model_weights)
#      52 print(f"Best model saved at {SAVE_PATH}")
# ---> 53 confusion_matrix(model, val_loader)
#      55 return train_losses, train_accs, val_losses, val_accs
#
# File d:\02-personal\01_ms ai\git-repo\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:208, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 to_ignore += ["self", "cls"]
#     206 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 208 validate_parameter_constraints(
#     209     parameter_constraints, params, caller_name=func.__qualname__
#     210 )
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
#
# File d:\02-personal\01_ms ai\git-repo\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'y_true' parameter of confusion_matrix must be an array-like. Got DeepMLP(
#   (fc1): Linear(in_features=1936, out_features=512, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc5): Linear(in_features=64, out_features=15, bias=True)
#   (drop_light): Dropout(p=0.2, inplace=False)
#   (drop_heavy): Dropout(p=0.4, inplace=False)
# ) instead.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
for name, grads in grad_history.items():
    if 'weight' in name: # Focus on weights, ignore biases for clarity
        plt.plot(grads, label=name)

plt.title("Gradient Magnitudes per Layer")
plt.xlabel("Iterations")
plt.ylabel("L2 Norm of Gradient")
plt.legend()
plt.yscale('log') # Use log scale because magnitudes vary wildly
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# After training is done:
print(best_model_weights)
deep_model.load_state_dict(best_model_weights)
deep_model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for images, labels in val_loader:
        outputs = deep_model(images.to(DEVICE))
        all_preds.extend(outputs.argmax(1).cpu().numpy())
        all_labels.extend(labels.numpy())

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
def run_predictions():
  print(f"Evaluation on Test Set:")

  all_predictions = []
  deep_model.eval()
  with torch.no_grad():
    for images in test_loader:
      images = images.to(DEVICE)

      hog_features = get_hog_features(images)
      flat_images = images.view(-1, 784)
      images = torch.cat((flat_images, hog_features), dim=1)
      
      outputs = deep_model(images)
      _, predictions = torch.max(outputs, 1)
      all_predictions.extend(predictions.cpu().numpy().tolist())

  return all_predictions


predictions = run_predictions()
predictions_string = ",".join(map(str, predictions))

output_file = "predictions.txt"

with open(output_file, "w") as f:
    f.write(predictions_string)
    
print(f"Predictions saved to {output_file}")
